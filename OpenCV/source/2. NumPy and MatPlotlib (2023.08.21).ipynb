# %% [markdown]
# # 3장. NumPy and MatPlotlib

# %%
# p.96
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('../insightbook.opencv_project_python-master/img/girl.jpg')

plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# * 왜 OpenCV는 BGR 포맷을 쓸까?
# * https://blog.xcoda.net/102

# %%
# OpneCV로 읽은 이미지 RGB로 변경
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('../insightbook.opencv_project_python-master/img/girl.jpg')
plt.imshow(img[:,:,::-1])
plt.xticks([])
plt.yticks([])
plt.show()
