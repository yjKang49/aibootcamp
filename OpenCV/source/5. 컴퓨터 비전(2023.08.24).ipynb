# %% [markdown]
# # 컴퓨터 비전(computer vision)
# ### 수업자료
# * "C:\Users\lenovo\Documents\aibootcamp\OpenCV\컴퓨터비전1.pdf"
# * PPT에 참고자료 링크 많음

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     C:\Users\lenovo\anaconda3
# STR                   *  C:\Users\lenovo\anaconda3\envs\STR

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 합성곱 신경망(CNN)
# * AlexNet (2012)
# * VGGNet (2014)
# * ResNet (2015)
# * DenseNet (2016)
# * NasNet (2018)
# * EfficientNet (2020)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## YOLO 참고자료<br>
#
# ###  yolo 논문
#
# * https://arxiv.org/pdf/1809.02165v1.pdf?fbclid=IwAR2_FnOpBS_scTRJv0EMR-dCPywWYLP3pTgXHoahtOjfp2XfiEH6eujmqKw
#
# ### yolo 논문 한글 사이트 (좋음)
#
# * https://medium.com/curg/you-only-look-once-%EB%8B%A4-%EB%8B%A8%EC%A7%80-%ED%95%9C-%EB%B2%88%EB%A7%8C-%EB%B3%B4%EC%95%98%EC%9D%84-%EB%BF%90%EC%9D%B4%EB%9D%BC%EA%B5%AC-bddc8e6238e2
# <br>
#
# ### Object detection for self-driving cars : yolo(구현)
#
# * https://www.hackerearth.com/blog/developers/object-detection-for-self-driving-cars/  (***)
# * https://docs.opencv.org/3.4/da/d9d/tutorial_dnn_yolo.html

# %% [markdown]
# ## 비전 트랜스포머(Vision Transformer)
# * 이미지 분야에서 attention 기법을 사용할 경우 대부분 CNN과 함께 사용되거나 전체 CNN구조를 유지하면서 CNN의 특정 구성 요소를 대체하는데 사용
# * CNN에 의존하지 않고 이미지 패치의 시퀀스를 입력값으로 사용하는 transformer를 적용
# ### vision Trasformer(ViT) 장점
# * transformer 구조를 거의 그대로 사용하기 때문에 확장성이 좋음
# * large 스케일 학습에서 매우 우수한 성능을 보임
# * transfer learning 시 CNN보다 훈련에 더 적은 계산 리소스를 사용
# ### Vision Trasformer(ViT) 단점
# * inductive bias의 부족으로 인해 CNN보다 데이터가 많이 요구됨
# 예를들어, 중간 사이즈인 이미지넷을 강한 정규화없이 하습에 사용할 경우 유사한 기의 ResNet 보다 성능이 낮음

# %% [markdown]
# ![image.png](attachment:image.png)
