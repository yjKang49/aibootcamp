# %% [markdown]
# # 3장. 숫자세계로 떠난 자연어
# ## 1. 미리 학습된 언어 모델
# ### 언어모델(language model)
# * 단어 시퀀스에 확률을 부여하는 모델
# * 단어 시퀀스를 입력받아 해당 시퀀스가 얼마나 그럴듯한지 확률을 출력하는 모델.
# <br>
# $ P(운전|난폭) = \cfrac{P(난폭, 운전)}{P(난폭)}$
# * 난폭이 나타난 다음에 운전이 나타날 확률(조건부확률)
# * 결과가 되는 사건(운전)은 조건이 되는 사건(난폭)의 영향을 받아 변한다는 개념 내포
# ### 순방향 언어 모델
# * 문장 앞부터 뒤로, 사람이 이해하는 순서대로 계산하는 모델
# * GPT, ELMo 같은 모델이이런 방식으로 프리트레인함
# ### 역방향 언어 모델
# * 문장 뒤부터 앞으로 계산하는 모델
# * ELMo 같은 모델이 이런 방식으로 프리트레인함
# * EMLo는 순방향과 역방향 언어 모델 모두 활용하는 기법
# ## 트랜스포머 살펴보기
# ![image.png](attachment:image.png)
#
#
# ### 참고자료
# * 교재: Do it! BERT와 GPT로 배우는 자연어 처리
#
# * "C:\Users\lenovo\Documents\aibootcamp\Natural Language Processing\3장 숫자세계로 떠난 자연어.pdf"
# * 인코더의 셀프 어텐션, 이점, Q, K, V의 정의
#     * https://velog.io/@cha-suyeon/%EC%9D%B8%EC%BD%94%EB%8D%94%EC%9D%98-%EC%85%80%ED%94%84-%EC%96%B4%ED%85%90%EC%85%98-%EC%9D%B4%EC%A0%90-Q-K-V%EC%9D%98-%EC%A0%95%EC%9D%98
# * 트랜스포머(transformer) 이해하기
#     * https://codingopera.tistory.com/43
# * HuggingFace transformers library
#     * NLP 기술을 많이 이들이 편히 이용할 수 있도록 기술민주화를 하는 그룹
#     * NLP 관련된 많은 라이브러리, 모델을 제공
#     * pretrained(학습된) 모델 제공
#     * https://huggingface.co/
#     * https://huggingface.co/models
#     * https://huggingface.co/transformers/v3.5.1/main_classes/tokenizer.html
