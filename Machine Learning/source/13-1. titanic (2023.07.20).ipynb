# %%
import warnings
warnings.filterwarnings(action = 'ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %%
gs=pd.read_csv('../data/titanic/gender_submission.csv')

# %%
test_data = pd.read_csv('../data/titanic/test.csv')

# %%
test_data
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train_data = pd.read_csv('../data/titanic/train.csv')

# %%
tmp = []
for each in train_data['Sex']:
    if each =='female':
        tmp.append(0)
    elif each =='male':
        tmp.append(1)
    else:
        tmp.append(np.nan)

# %%
train_data['Sex']=tmp
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
tmp = []
for each in test_data['Sex']:
    if each =='female':
        tmp.append(0)
    elif each =='male':
        tmp.append(1)
    else:
        tmp.append(np.nan)
            
test_data['Sex']=tmp
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data = train_data [train_data['Age'].notnull()]
train_data = train_data [train_data['SibSp'].notnull()]
train_data = train_data [train_data['Parch'].notnull()]
train_data = train_data [train_data['Fare'].notnull()]
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 714 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  714 non-null    int64
#  1   Survived     714 non-null    int64
#  2   Pclass       714 non-null    int64
#  3   Name         714 non-null    object
#  4   Sex          714 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        714 non-null    int64
#  7   Parch        714 non-null    int64
#  8   Ticket       714 non-null    object
#  9   Fare         714 non-null    float64
#  10  Cabin        185 non-null    object
#  11  Embarked     712 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 72.5+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    int64
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 36.0+ KB

# %%
train_pre= train_data[['Pclass','Sex','SibSp','Parch']]
train_pre.head()
# Out:
#    Pclass  Sex  SibSp  Parch
# 0       3    1      1      0
# 1       1    0      1      0
# 2       3    0      0      0
# 3       1    0      1      0
# 4       3    1      0      0

# %%
test_pre= test_data[['Pclass','Sex','SibSp','Parch']]
test_pre.head()
# Out:
#    Pclass  Sex  SibSp  Parch
# 0       3    1      0      0
# 1       3    0      1      0
# 2       2    1      0      0
# 3       3    1      0      0
# 4       3    0      1      1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test=train_test_split(train_pre,train_data[['Survived']], test_size=0.2,random_state=13)

# %%
from sklearn.ensemble import RandomForestClassifier
Ran_clf= RandomForestClassifier(n_estimators=13)
Ran_clf.fit(X_train,y_train)
print('Score:{}'.format(Ran_clf.score(X_train,y_train)))
# Out:
# Score:0.8108581436077058

# %%
submission = pd.DataFrame({'PassengerId':test_data['PassengerId'],'Survived':Ran_clf.predict(test_pre)})

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
submission.to_csv('../data/titanic/titanic_predict1.csv',index=False)
