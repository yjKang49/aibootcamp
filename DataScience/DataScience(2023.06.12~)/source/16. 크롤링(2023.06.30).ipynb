# %% [markdown]
# # 웹크롤링

# %% [markdown]
# ## beautifulSoup
# * 홈페이지 내 데이터를 쉽게 추출할 수 있도록 도와주는 파이썬 외부 라이브러리
# * 웹문서 내 수많은 HTML 태그들을 파서(parser)를 활용해 사용하기 좋은 형태로 제공
# * 외부라이브러리이기 때문에 pip을 활용해 설치해주어야 사용가능
# * 참고자료 <br>
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# # 샌드위치 맛집 분석
# * HTML 은 hypertext markup language E의 약자
# * 파싱
# https://ko.wikipedia.org/wiki/%EA%B5%AC%EB%AC%B8_%EB%B6%84%EC%84%9D

# %%
from bs4 import BeautifulSoup

# %%
page = open('C:/aibootcamp/python/21일차(2023.06.30)/test.html', encoding= 'utf-8').read()
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())     # BeautifulSoup 에서 파싱 처리한 파서 트리를 유니코드 형태로 리턴하는 함수
# .prettify() 옵션은 html 페이지의 내용 전체를 보고자 할 때
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML code
#   </title>
#   <style>
#    div #second { color: red; font-size: 30px; }
#   </style>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" hover="hover()" id="first">
#     NAVER
#     <a href="https://www.naver.com">
#      네이버
#     </a>
#    </p>
#    <p class="inner-text second-item" id="second">
#     python document
#     <a href="https://www.python.org" id="py-link">
#      python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="third">
#    <b>
#     DataScience is fun.
#    </b>
#   </p>
#   <p class="outer-text first-item" id="fourth">
#    <b>
#     DataScience good.
#                 DataScience good2.
#    </b>
#   </p>
#   <script>
#   </script>
#  </body>
# </html>

# %%
print(soup.find_all('a'))
# Out:
# [<a href="https://www.naver.com">네이버</a>, <a href="https://www.python.org" id="py-link">python</a>]

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>
#              Very Simple HTML code
#          </title>
#  <style>
#              div #second { color: red; font-size: 30px; }
#          </style>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" hover="hover()" id="first">
#                  NAVER
#                  <a href="https://www.naver.com">네이버</a>
#  </p>
#  <p class="inner-text second-item" id="second">
#                  python document
#                  <a href="https://www.python.org" id="py-link">python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="third">
#  <b>
#                  DataScience is fun.
#              </b>
#  </p>
#  <p class="outer-text first-item" id="fourth">
#  <b>
#                  DataScience good.
#                  DataScience good2.
#              </b>
#  </p>
#  <script>
#  </script>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]   #html 태그에 접속하고싶다면
html
# Out:
# <html>
# <head>
# <title>
#             Very Simple HTML code
#         </title>
# <style>
#             div #second { color: red; font-size: 30px; }
#         </style>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" hover="hover()" id="first">
#                 NAVER
#                 <a href="https://www.naver.com">네이버</a>
# </p>
# <p class="inner-text second-item" id="second">
#                 python document
#                 <a href="https://www.python.org" id="py-link">python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="third">
# <b>
#                 DataScience is fun.
#             </b>
# </p>
# <p class="outer-text first-item" id="fourth">
# <b>
#                 DataScience good.
#                 DataScience good2.
#             </b>
# </p>
# <script>
# </script>
# </body>
# </html>

# %%
body = list(html.children)[3]    #html 태그의 children 중 3번째를 조사. 0부터 시작하지x
body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" hover="hover()" id="first">
#                 NAVER
#                 <a href="https://www.naver.com">네이버</a>
# </p>
# <p class="inner-text second-item" id="second">
#                 python document
#                 <a href="https://www.python.org" id="py-link">python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="third">
# <b>
#                 DataScience is fun.
#             </b>
# </p>
# <p class="outer-text first-item" id="fourth">
# <b>
#                 DataScience good.
#                 DataScience good2.
#             </b>
# </p>
# <script>
# </script>
# </body>

# %%
# children을 이용해서 태그를 조사할 수도 있고 한 번에 나타낼 수도 있다. 
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" hover="hover()" id="first">
#                 NAVER
#                 <a href="https://www.naver.com">네이버</a>
# </p>
# <p class="inner-text second-item" id="second">
#                 python document
#                 <a href="https://www.python.org" id="py-link">python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="third">
# <b>
#                 DataScience is fun.
#             </b>
# </p>
# <p class="outer-text first-item" id="fourth">
# <b>
#                 DataScience good.
#                 DataScience good2.
#             </b>
# </p>
# <script>
# </script>
# </body>

# %%
soup.head
# Out:
# <head>
# <title>
#             Very Simple HTML code
#         </title>
# <style>
#             div #second { color: red; font-size: 30px; }
#         </style>
# </head>

# %%
soup.head.style
# Out:
# <style>
#             div #second { color: red; font-size: 30px; }
#         </style>

# %%
list(body.children)   # body 태그의 자식태그의 리스트
# Out:
# ['\n',
#  <div>
#  <p class="inner-text first-item" hover="hover()" id="first">
#                  NAVER
#                  <a href="https://www.naver.com">네이버</a>
#  </p>
#  <p class="inner-text second-item" id="second">
#                  python document
#                  <a href="https://www.python.org" id="py-link">python</a>
#  </p>
#  </div>,
#  '\n',
#  <p class="outer-text first-item" id="third">
#  <b>
#                  DataScience is fun.
#              </b>
#  </p>,
#  '\n',
#  <p class="outer-text first-item" id="fourth">
#  <b>
#                  DataScience good.
#                  DataScience good2.
#              </b>
#  </p>,
#  '\n',
#  <script>
#  </script>,
#  '\n']

# %%
# 접근해야할 태그를 알고있다면 find, find_all 명령을 사용
soup.find_all('p')   # 상위태그.find_all('p') 상위태그밑의 모든 p를 찾아준다
# Out:
# [<p class="inner-text first-item" hover="hover()" id="first">
#                  NAVER
#                  <a href="https://www.naver.com">네이버</a>
#  </p>,
#  <p class="inner-text second-item" id="second">
#                  python document
#                  <a href="https://www.python.org" id="py-link">python</a>
#  </p>,
#  <p class="outer-text first-item" id="third">
#  <b>
#                  DataScience is fun.
#              </b>
#  </p>,
#  <p class="outer-text first-item" id="fourth">
#  <b>
#                  DataScience good.
#                  DataScience good2.
#              </b>
#  </p>]

# %%
soup.find('p')   #첫번째 p 태그를 찾는다
# Out:
# <p class="inner-text first-item" hover="hover()" id="first">
#                 NAVER
#                 <a href="https://www.naver.com">네이버</a>
# </p>

# %%
# p태그의 class가 outer_text 인 것을 찾아줍니다.
soup.find_all('p', class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="third">
#  <b>
#                  DataScience is fun.
#              </b>
#  </p>,
#  <p class="outer-text first-item" id="fourth">
#  <b>
#                  DataScience good.
#                  DataScience good2.
#              </b>
#  </p>]

# %%
soup.find_all(id = 'first')
# Out:
# [<p class="inner-text first-item" hover="hover()" id="first">
#                  NAVER
#                  <a href="https://www.naver.com">네이버</a>
#  </p>]

# %%
soup.find('p')   # find 명령은 제일 처음 나타난 태그만 찾아줌
# Out:
# <p class="inner-text first-item" hover="hover()" id="first">
#                 NAVER
#                 <a href="https://www.naver.com">네이버</a>
# </p>

# %%
soup.head
# Out:
# <head>
# <title>
#             Very Simple HTML code
#         </title>
# <style>
#             div #second { color: red; font-size: 30px; }
#         </style>
# </head>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>
#              Very Simple HTML code
#          </title>
#  <style>
#              div #second { color: red; font-size: 30px; }
#          </style>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" hover="hover()" id="first">
#                  NAVER
#                  <a href="https://www.naver.com">네이버</a>
#  </p>
#  <p class="inner-text second-item" id="second">
#                  python document
#                  <a href="https://www.python.org" id="py-link">python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="third">
#  <b>
#                  DataScience is fun.
#              </b>
#  </p>
#  <p class="outer-text first-item" id="fourth">
#  <b>
#                  DataScience good.
#                  DataScience good2.
#              </b>
#  </p>
#  <script>
#  </script>
#  </body>
#  </html>]

# %%
soup.head.next_sibling   #soup 의 head 다음에 줄바꿈 문자가 있습니다.
# Out:
# '\n'

# %%
soup.head.previous_sibling
# Out:
# '\n'

# %%
soup.head.next_sibling.next_sibling
# Out:
# <body>
# <div>
# <p class="inner-text first-item" hover="hover()" id="first">
#                 NAVER
#                 <a href="https://www.naver.com">네이버</a>
# </p>
# <p class="inner-text second-item" id="second">
#                 python document
#                 <a href="https://www.python.org" id="py-link">python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="third">
# <b>
#                 DataScience is fun.
#             </b>
# </p>
# <p class="outer-text first-item" id="fourth">
# <b>
#                 DataScience good.
#                 DataScience good2.
#             </b>
# </p>
# <script>
# </script>
# </body>

# %%
body.p    #제일 처음 나타나는 p 태그
# Out:
# <p class="inner-text first-item" hover="hover()" id="first">
#                 NAVER
#                 <a href="https://www.naver.com">네이버</a>
# </p>

# %%
body.p.next_sibling.next_sibling
# Out:
# <p class="inner-text second-item" id="second">
#                 python document
#                 <a href="https://www.python.org" id="py-link">python</a>
# </p>

# %%
for each_tag in soup.find_all('p'):
    print(each_tag.get_text())
# Out:
#                 NAVER
#                 네이버
#
#
#                 python document
#                 python
#
#
#
#                 DataScience is fun.
#
#
#
#
#                 DataScience good.
#                 DataScience good2.

# %%
for each_tag in soup.find_all('p')[3]:     # p태그의 일부만 뽑아오는 방법
    print(each_tag.get_text())
# Out:
#                 DataScience good.
#                 DataScience good2.

# %%
# 태그가 있던 자리는 줄바꿈(\n)이 표시되고 전체 텍스트를 보여줌
body.get_text()
# Out:
# '\n\n\n                NAVER\n                네이버\n\n\n                python document\n                python\n\n\n\n\n                DataScience is fun.\n            \n\n\n\n                DataScience good.\n                DataScience good2.\n            \n\n\n'

# %%
# 클릭 가능한 링크인 a 태그를 찾습니다.
links = soup.find_all('a')
links
# Out:
# [<a href="https://www.naver.com">네이버</a>,
#  <a href="https://www.python.org" id="py-link">python</a>]

# %%
# href 속성을 찾으면 링크 주소를 얻을 수 있다.
for each in links:
    href = each['href']
    text = each.string
    print( text + ' => ' + href )
# Out:
# 네이버 => https://www.naver.com
# python => https://www.python.org

# %% [markdown]
# # 크롬 개발자도구를 이용해서 원하는 태그 찾기

# %%
from urllib.request import urlopen

# %%
url = 'https://finance.naver.com/marketindex/'    # F12
page = urlopen(url)
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230704202526/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20230704202526/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
soup.find_all('span', 'value')[0].string   #span의 class명이 value 인걸 찾음
# Out:
# '1,302.00'

# %% [markdown]
# # 실전: 시카고 샌드위치 맛집 소개 사이트에 접근하기
# * https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/

# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen

url_base = 'https://www.chicagomag.com'
url_sub = '/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/'
url = Request(url_base + url_sub, headers = {'User-Agent': 'Mozilla/5.0'})    # 로봇이 아닙니다 통과하려구
html = urlopen(url)
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js"></script>
# <title>The 50 Best Sandwiches in Chicago – Chicago Magazine</title>
# <style type="text/css">
# 					.heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# 							background-color: #000!important;
# ...

# %%
print(soup.find_all('div', 'sammy'))
# Out:
# [<div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">2</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/"><b>Fried Bologna</b><br/>
# Au Cheval<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">3</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/"><b>Woodland Mushroom</b><br/>
# Xoco<br/>
# <em>Read more</em> </a></div>
# </div>, <div class="sammy" style="position: relative;">
# <div class="sammyRank">4</div>
# ...

# %%
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %%
print(soup.find_all('div', 'sammy')[0])
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %%
print(soup.find_all('div', 'sammy')[5])
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">6</div>
# <div class="sammyListing"><a href="https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Hendrickx-Belgian-Bread-Crafter-Belgian-Chicken-Curry-Salad/"><b>Belgian Chicken Curry Salad</b><br/>
# Hendrickx Belgian Bread Crafter<br/>
# <em>Read more</em> </a></div>
# </div>

# %% [markdown]
# # 접근한 웹페이지에서 원하는 데이터 추출하고 정리하기

# %%
tmp_one = soup.find_all('div', 'sammy')[0]   #div의 sammy 클래스인 모든 항목을 가져온다. 그 중 첫번째 항목
type(tmp_one)
# Out:
# bs4.element.Tag

# %%
tmp_one.find(class_ = 'sammyRank')         # 'class_' 임에 주의
# Out:
# <div class="sammyRank">1</div>

# %%
tmp_one.find(class_ = 'sammyRank').get_text()
# Out:
# '1'

# %%
tmp_one.find(class_ = 'sammyListing')
# Out:
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>

# %%
# 메뉴 이름과 가게 이름이 같이 나옴
tmp_one.find(class_ = 'sammyListing').get_text()
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
tmp_one.find('a')['href']      # a는 링크 연결하는 태그 일부, href 딕셔너리 타입
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
# 위의 'BLT\nOld Oak Tap\nRead more ' 에서 '\n' 을 제거한다

import re     #정규표현식(Regular Express)

tmp_string = tmp_one.find(class_ = 'sammyListing').get_text()
# split ==> 지정한 특정 패턴이 일치하면 분리
re.split(('\n'), tmp_string)

print(re.split(('\n'), tmp_string)[0])   #메뉴 이름
print(re.split(('\n'), tmp_string)[1])   #가게 이름
# Out:
# BLT
# Old Oak Tap

# %%
# 절대경로로 잡힌 url은 그대로 두고 상대경로로 잡힌 url은 절대경로로 변경
from urllib.parse import urljoin

# %%
rank = []    #rank 순위
main_menu = [] #메인 메뉴 이름
cafe_name = []  #카페 이름
url_add = []  #접근주소 url
list_soup = soup.find_all('div', 'sammy')
for item in list_soup:
    rank.append(item.find(class_= 'sammyRank').get_text())
    tmp_string = item.find(class_= 'sammyListing').get_text()   
    main_menu.append(re.split(('\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n'), tmp_string)[1])
    url_add.append(urljoin(url_base, item.find('a')['href'] ))

# %%
rank[ :5]
# Out:
# ['1', '2', '3', '4', '5']

# %%
cafe_name[:5]
# Out:
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']

# %% [markdown]
# ## 주피터 노트북에서 상태 진행바를 쉽게 만들어주는 모듈
# * pip install tqdm

# %%
# !pip install tqdm

# %%
from tqdm import tqdm_notebook
import time

rank = []    #rank 순위
main_menu = [] #메인 메뉴 이름
cafe_name = []  #카페 이름
url_add = []  #접근주소 url
list_soup = soup.find_all('div', 'sammy')
bar_total = tqdm_notebook(list_soup)

for item in bar_total:
    rank.append(item.find(class_= 'sammyRank').get_text())
    tmp_string = item.find(class_= 'sammyListing').get_text()
    
    main_menu.append(re.split(('\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n'), tmp_string)[1])
    url_add.append(urljoin(url_base, item.find('a')['href'] ))
    
    time.sleep(0.05)       # 긁어올때 시간을 부여. 프로그램실행할때 시간여유를 줘서 충분히 데이터를 긁어올 수 있도록.
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_23860\3384156668.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   bar_total = tqdm_notebook(list_soup)
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
len(rank), len(main_menu), len(cafe_name), len(url_add)
# Out:
# (50, 50, 50, 50)

# %%
rank[:5]
# Out:
# ['1', '2', '3', '4', '5']

# %%
main_menu[:5]
# Out:
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']

# %%
cafe_name[:5]
# Out:
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']

# %%
url_add[:5]
# Out:
# ['https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/']

# %%
import pandas as pd
data = {'Rank': rank, 'Menu': main_menu, 'Cafe': cafe_name, 'URL': url_add}
df = pd.DataFrame(data)
df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df = pd. DataFrame(data, columns = ['Rank', 'Cafe', 'Menu', 'URL'])
df.head()
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df.to_csv('../data/python_data/best_sandwiches_chicago11.csv', sep=',', encoding='UTF-8')   # 크롤링해온 데이터를 csv 파일로 저장

# %% [markdown]
# ## 다수의 웹페이지에 접근하여 원하는정보 가져오기

# %%
df = pd.read_csv('../data/python_data/best_sandwiches_chicago11.csv', index_col = 0 ) # 크롤링해온 데이터를 저장한 csv 파일
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df['URL'][0]
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
url = Request(df['URL'][0], headers = {'User-Agent': 'Mozilla/5.0'})    # 로봇이 아닙니다 통과하려구
html = urlopen(url)
soup_tmp = BeautifulSoup(html, 'html.parser')
soup_tmp
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js"></script>
# <title>1. Old Oak Tap BLT – Chicago Magazine</title>
# <style type="text/css">
# 					.heateor_sss_button_instagram span.heateor_sss_svg,a.heateor_sss_instagram span.heateor_sss_svg{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
# 						div.heateor_sss_horizontal_sharing a.heateor_sss_button_instagram span{background:#000!important;}div.heateor_sss_standard_follow_icons_container a.heateor_sss_button_instagram span{background:#000;}
# 										.heateor_sss_horizontal_sharing .heateor_sss_svg,.heateor_sss_standard_follow_icons_container .heateor_sss_svg{
# 							background-color: #000!important;
# 				background: #000!important;
# ...

# %%
print(soup_tmp.find('p', 'addy'))
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
price_tmp = soup_tmp.find('p', 'addy').get_text()
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
price_tmp.split()
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']

# %%
price_tmp.split()[0]
# Out:
# '$10.'

# %%
price_tmp.split()[0][:-1]      # price_tmp.split()[0] 의 결과에서 문자열의 맨 마지막을 제외한 처음부터 끝까지 가져온다.
# Out:
# '$10'

# %%
price_tmp.split()[1:-2]
# Out:
# ['2109', 'W.', 'Chicago', 'Ave.,']

# %%
' '.join(price_tmp.split()[1:-2])
# Out:
# '2109 W. Chicago Ave.,'

# %% [markdown]
# ## 샌드위치 페이지 50개에 접근하기

# %%
# tqdm ==> 현 상태를 바(bar)의 형태로 표현
from tqdm import tqdm_notebook
price = []
address = []

for n in tqdm_notebook(df.index):
    url = Request(df['URL'][n], headers = {'User-Agent': 'Mozilla/5.0'})    # 로봇이 아닙니다 통과하려구
    html = urlopen(url)
    soup_tmp = BeautifulSoup(html, 'lxml')

    gettings = soup_tmp.find('p', 'addy').get_text()
    
    price.append(gettings.split()[0][:-1])
    address.append(' '.join(gettings.split()[1:-2]))
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_23860\2722888303.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(df.index):
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# ## 50개 웹 페이지에 대한 정보 가져오기

# %%
address
# Out:
# ['2109 W. Chicago Ave.,',
#  '800 W. Randolph St.,',
#  '445 N. Clark St.,',
#  '914 Noyes St., Evanston,',
#  '825 W. Fulton Mkt.,',
#  '100 E. Walton',
#  '1639 S. Wabash Ave.,',
#  '2211 W. North Ave.,',
#  '3619 W. North Ave.,',
#  '3267 S. Halsted St.,',
#  '2537 N. Kedzie Blvd.,',
#  'Multiple',
#  '3124 N. Broadway,',
#  '3455 N. Southport Ave.,',
#  '2657 N. Kedzie Ave.,',
#  '1120 W. Grand Ave.,',
#  '1141 S. Jefferson St.,',
#  '333 E. Benton Pl.,',
#  '1411 N. Wells St.,',
#  '1747 N. Damen Ave.,',
#  '3209 W. Irving Park',
#  'Multiple',
#  '5347 N. Clark St.,',
#  '2954 W. Irving Park Rd.,',
#  'Multiple',
#  '191 Skokie Valley Rd., Highland Park,',
#  'Multiple',
#  '1818 W. Wilson Ave.,',
#  '2517 W. Division St.,',
#  '218 W. Kinzie',
#  'Multiple',
#  '1547 N. Wells St.,',
#  '415 N. Milwaukee Ave.,',
#  '1840 N. Damen Ave.,',
#  '1220 W. Webster Ave.,',
#  '5357 N. Ashland Ave.,',
#  '1834 W. Montrose Ave.,',
#  '615 N. State St.,',
#  'Multiple',
# ...

# %%
price
# Out:
# ['$10',
#  '$9',
#  '$9.50',
#  '$9.40',
#  '$10',
#  '$7.25',
#  '$16',
#  '$10',
#  '$9',
#  '$17',
#  '$11',
#  '$5.49',
#  '$14',
#  '$10',
#  '$13',
#  '$4.50',
#  '$11.95',
#  '$11.50',
#  '$6.25',
#  '$15',
#  '$5',
#  '$6',
#  '$8',
#  '$5.99',
#  '$7.52',
#  '$11.95',
#  '$7.50',
#  '$12.95',
#  '$7',
#  '$21',
#  '$9.79',
#  '$9.75',
#  '$13',
#  '$7.95',
#  '$9',
#  '$9',
#  '$8',
#  '$8',
#  '$7',
#  '$6',
#  '$7.25',
#  '$11',
#  '$6',
#  '$9',
#  '$5.49',
#  '$8',
#  '$6.50',
#  '$7.50',
#  '$8.75',
#  '$6.85']

# %%
df.head()
# Out:
#    Rank                    Cafe               Menu  \
# 0     1             Old Oak Tap                BLT
# 1     2               Au Cheval      Fried Bologna
# 2     3                    Xoco  Woodland Mushroom
# 3     4               Al’s Deli         Roast Beef
# 4     5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
len(price), len(address), len(df)
# Out:
# (50, 50, 50)

# %%
df['Price'] = price
df['Address'] = address
df = df.loc[:, ['Rank', 'Cafe', 'Menu', 'Price','Address']]
df.set_index('Rank', inplace = True)
df.head()
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
df.to_csv('../data/python_data/best_sandwiches_chicago2.csv', sep=',', encoding='UTF-8')

# %% [markdown]
# ## 맛집 위치를 지도에 표기하기

# %%
import folium 
import pandas as pd
import googlemaps
import numpy as np

# %%
df = pd.read_csv('../data/python_data/03. best_sandwiches_list_chicago2.csv', index_col = 0)  
df.head(5)        # unnamed:0 이라는 열이 새로 생기는걸 방지하기 위해 index_col = 0을 설정함
# Out:
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
gmaps_key = 'AIzaSyDofNv_8UFi3WTalQQB2pfFSat5k_gB1oc'   # 개인에게 할당된 구글 맵스 api 키를 입력. 
gmaps = googlemaps.Client(key = gmaps_key)

# %%
lat = []
lng = []
for n in tqdm_notebook(df.index):
    if df['Address'][n] != 'Multiple':
        target_name = df['Address'][n] + ', ' + 'Cicago'
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    else:
        lat.append(np.nan)
        lng.append(np.nan)
df['lat'] = lat
df['lng'] = lng
df.head()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_23860\2107916153.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm_notebook(df.index):
#   0%|          | 0/50 [00:00<?, ?it/s]
#                         Cafe               Menu  Price  \
# Rank
# 1                Old Oak Tap                BLT    $10
# 2                  Au Cheval      Fried Bologna     $9
# 3                       Xoco  Woodland Mushroom  $9.50
# 4                  Al’s Deli         Roast Beef  $9.40
# 5     Publican Quality Meats               PB&L    $10
#
#                        Address        lat        lng
# Rank
# 1        2109 W. Chicago Ave.,  41.895558 -87.679967
# 2         800 W. Randolph St.,  41.884639 -87.647590
# 3            445 N. Clark St.,  41.890523 -87.630783
# 4     914 Noyes St., Evanston,  42.058322 -87.683748
# 5          825 W. Fulton Mkt.,  41.886604 -87.648536

# %%
len(lat), len(lng)   #길이가 50개인지 확인
# Out:
# (50, 50)

# %%
mapping = folium.Map(location = [df['lat'].mean(), df['lng'].mean()], zoom_start = 11 )

for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]], popup = df['Cafe'][n]).add_to(mapping)
        
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import MarkerCluster
mapping = folium.Map(location = [df['lat'].mean(), df['lng'].mean()], zoom_start = 11 )   
#데이터들의 위도와 경도의 평균을 초점으로 나타나도록
marker_cluster = MarkerCluster().add_to(mapping)   #마커클러스터


for n in df.index:
    if df['Address'][n] != 'Multiple':
        folium.Marker([df['lat'][n], df['lng'][n]], popup = df['Cafe'][n]).add_to(mapping).add_to(marker_cluster)
        
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
