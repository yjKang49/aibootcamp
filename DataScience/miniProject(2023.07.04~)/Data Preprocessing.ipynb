# %% [markdown]
# # 데이터 전처리
# * pastic 데이터에 분기와 구(강남구)가 일치하도록 그룹화하여 매출금액,매출건수를 새컬럼으로 만들어서 insert 주중매출데이터(요일 모두 살려서), 주말매출데이터 등 되도록 모든 컬럼을 살리는 방식으로.
# * date_new 밑의 '월별_서울시_상관분석서비스~' 데이터폴더와 '플라스틱량~' 폴더 참고하여 데이터전처리 진행.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../../../Downloads/월별서울시상관분석서비스/서울시_우리마을가게_상권분석서비스(신_상권배후지_추정매출)_2021년.csv', sep = ',' , encoding='cp949' )
df
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명 서비스_업종_코드  \
# 0          2021         1        A       골목상권  2110001   이북5도청사  CS100001
# 1          2021         1        A       골목상권  2110001   이북5도청사  CS100005
# 2          2021         1        A       골목상권  2110001   이북5도청사  CS100008
# 3          2021         1        A       골목상권  2110001   이북5도청사  CS100009
# 4          2021         1        A       골목상권  2110001   이북5도청사  CS100010
# ...         ...       ...      ...        ...      ...      ...       ...
# 192972     2021         4        A       골목상권  2111090  강일동주민센터  CS300016
# 192973     2021         4        A       골목상권  2111090  강일동주민센터  CS300018
# 192974     2021         4        A       골목상권  2111090  강일동주민센터  CS300020
# 192975     2021         4        A       골목상권  2111090  강일동주민센터  CS300021
# 192976     2021         4        A       골목상권  2111090  강일동주민센터  CS300022
#
#        서비스_업종_코드_명   분기당_매출_금액  분기당_매출_건수  ...  시간대_건수~24_매출_건수  남성_매출_건수  \
# ...

# %%
df.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '분기당_매출_금액', '분기당_매출_건수', '주중_매출_비율',
#        '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
#        '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
#        '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
#        '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
#        '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
#        '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
# ...

# %%
df.shape
# Out:
# (192977, 80)

# %%
df2 = pd.read_csv('../../../Downloads/서울시 상권분석서비스(상권영역).csv', sep = ',' , encoding='cp949' )
df2
# Out:
#       기준_년월_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  엑스좌표_값  와이좌표_값  \
# 0       202112        A       골목상권  2110753   시흥동 은행나무사거리  191934  438813
# 1       202112        A       골목상권  2110427    노원 을지대학교병원  206265  459431
# 2       202112        A       골목상권  2110755      동일여자고등학교  192300  439070
# 3       202112        A       골목상권  2110739    시흥3동 우편취급국  191289  438014
# 4       202112        A       골목상권  2111017      송파나루역 3번  210222  445516
# ...        ...      ...        ...      ...           ...     ...     ...
# 1666    202112        U       관광특구  1001493  동대문패션타운 관광특구  200974  451975
# 1667    202112        U       관광특구  1001494    종로?청계 관광특구  199768  452273
# 1668    202112        U       관광특구  1001495       잠실 관광특구  210191  446339
# 1669    202112        U       관광특구  1001496   강남 마이스 관광특구  205310  445727
# 1670    202112        U       관광특구  1001491      이태원 관광특구  199503  448326
#
#       시군구_코드    행정동_코드  형태정보
# 0      11545  11545710   NaN
# ...

# %%
df2['상권_코드'].unique().shape     #상권코드unique 확인
# Out:
# (1671,)

# %%
df2 = df2.drop('형태정보', axis = 1)    #형태정보 컬럼 삭제
df2 = df2.drop('기준_년월_코드', axis = 1)    #형태정보 컬럼 삭제

# %%
#unnamed:0 나오는걸 없애기위해 index_col = 0, index 지정하는 방법
df3 = pd.read_csv('../../../Downloads/new_code_info_gu.csv', sep = ',' , encoding='cp949' , index_col = 0)  
df3
# Out:
#           Code     시도   시군구
# 1   1111000000  서울특별시   종로구
# 2   1114000000  서울특별시    중구
# 3   1117000000  서울특별시   용산구
# 4   1120000000  서울특별시   성동구
# 5   1121500000  서울특별시   광진구
# 6   1123000000  서울특별시  동대문구
# 7   1126000000  서울특별시   중랑구
# 8   1129000000  서울특별시   성북구
# 9   1130500000  서울특별시   강북구
# 10  1132000000  서울특별시   도봉구
# 11  1135000000  서울특별시   노원구
# 12  1138000000  서울특별시   은평구
# 13  1141000000  서울특별시  서대문구
# 14  1144000000  서울특별시   마포구
# 15  1147000000  서울특별시   양천구
# 16  1150000000  서울특별시   강서구
# 17  1153000000  서울특별시   구로구
# 18  1154500000  서울특별시   금천구
# 19  1156000000  서울특별시  영등포구
# 20  1159000000  서울특별시   동작구
# 21  1162000000  서울특별시   관악구
# 22  1165000000  서울특별시   서초구
# 23  1168000000  서울특별시   강남구
# 24  1171000000  서울특별시   송파구
# 25  1174000000  서울특별시   강동구

# %%
df3['시군구_코드'] = df3['Code'][:25]/100000     # Code컬럼의 뒤에서 5개 숫자빼고 gu_code로 저장

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 1 to 25
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Code    25 non-null     int64
#  1   시도      25 non-null     object
#  2   시군구     25 non-null     object
#  3   시군구_코드  25 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1000.0+ bytes

# %%
df3['시군구_코드'] = df3['시군구_코드'].apply(np.int64)    #gu_code의 타입 변경. float->int
df3
# Out:
#           Code     시도   시군구  시군구_코드
# 1   1111000000  서울특별시   종로구   11110
# 2   1114000000  서울특별시    중구   11140
# 3   1117000000  서울특별시   용산구   11170
# 4   1120000000  서울특별시   성동구   11200
# 5   1121500000  서울특별시   광진구   11215
# 6   1123000000  서울특별시  동대문구   11230
# 7   1126000000  서울특별시   중랑구   11260
# 8   1129000000  서울특별시   성북구   11290
# 9   1130500000  서울특별시   강북구   11305
# 10  1132000000  서울특별시   도봉구   11320
# 11  1135000000  서울특별시   노원구   11350
# 12  1138000000  서울특별시   은평구   11380
# 13  1141000000  서울특별시  서대문구   11410
# 14  1144000000  서울특별시   마포구   11440
# 15  1147000000  서울특별시   양천구   11470
# 16  1150000000  서울특별시   강서구   11500
# 17  1153000000  서울특별시   구로구   11530
# 18  1154500000  서울특별시   금천구   11545
# 19  1156000000  서울특별시  영등포구   11560
# 20  1159000000  서울특별시   동작구   11590
# 21  1162000000  서울특별시   관악구   11620
# 22  1165000000  서울특별시   서초구   11650
# 23  1168000000  서울특별시   강남구   11680
# 24  1171000000  서울특별시   송파구   11710
# 25  1174000000  서울특별시   강동구   11740

# %%
df3 = df3.drop('Code', axis =  1)
df3 = df3.drop('시도', axis = 1)    # 시도 컬럼 삭제

# %%
#df3.to_excel('../../../Downloads/preprocessing_info_gu.xlsx' , index = False)     # 구코드만 있는컬럼 생성

# %%
df3
# Out:
#      시군구  시군구_코드
# 1    종로구   11110
# 2     중구   11140
# 3    용산구   11170
# 4    성동구   11200
# 5    광진구   11215
# 6   동대문구   11230
# 7    중랑구   11260
# 8    성북구   11290
# 9    강북구   11305
# 10   도봉구   11320
# 11   노원구   11350
# 12   은평구   11380
# 13  서대문구   11410
# 14   마포구   11440
# 15   양천구   11470
# 16   강서구   11500
# 17   구로구   11530
# 18   금천구   11545
# 19  영등포구   11560
# 20   동작구   11590
# 21   관악구   11620
# 22   서초구   11650
# 23   강남구   11680
# 24   송파구   11710
# 25   강동구   11740

# %%
gu_merge = df2.merge(df3, left_on = '시군구_코드', right_on = '시군구_코드')
gu_merge
# Out:
#      상권_구분_코드 상권_구분_코드_명    상권_코드         상권_코드_명  엑스좌표_값  와이좌표_값  시군구_코드  \
# 0           A       골목상권  2110753     시흥동 은행나무사거리  191934  438813   11545
# 1           A       골목상권  2110755        동일여자고등학교  192300  439070   11545
# 2           A       골목상권  2110739      시흥3동 우편취급국  191289  438014   11545
# 3           A       골목상권  2110734           금천파출소  191061  439380   11545
# 4           A       골목상권  2110751           난곡중학교  191810  442086   11545
# ...       ...        ...      ...             ...     ...     ...     ...
# 1666        R       전통시장  2130268          상도전통시장  195759  444396   11590
# 1667        R       전통시장  2130271         남성역골목시장  197572  442683   11590
# 1668        R       전통시장  2130270            흑석시장  196727  445276   11590
# 1669        R       전통시장  2130269  강남시장(동작구 강남시장)  195874  444157   11590
# 1670        R       전통시장  2130272            사당시장  197801  442618   11590
#
#         행정동_코드  시군구
# 0     11545710  금천구
# 1     11545680  금천구
# ...

# %%
#gu_merge.to_excel('../../../Downloads/preprocessing_상권영역.xlsx' , index = False)   # 서울시 상권분석서비스(상권영역).csv에 구컬럼추가

# %%
cols_to_use = gu_merge.columns.difference(df.columns)      # df 의 컬럼과 비교했을 때 gu_merge에만 있는 컬럼들
cols_to_use
# Out:
# Index(['시군구', '시군구_코드', '엑스좌표_값', '와이좌표_값', '행정동_코드'], dtype='object')

# %%
district_merge = df.merge(gu_merge, left_on = '상권_코드', right_on = '상권_코드', suffixes=('', '_y'))
district_merge
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명 서비스_업종_코드  \
# 0          2021         1        A       골목상권  2110001   이북5도청사  CS100001
# 1          2021         1        A       골목상권  2110001   이북5도청사  CS100005
# 2          2021         1        A       골목상권  2110001   이북5도청사  CS100008
# 3          2021         1        A       골목상권  2110001   이북5도청사  CS100009
# 4          2021         1        A       골목상권  2110001   이북5도청사  CS100010
# ...         ...       ...      ...        ...      ...      ...       ...
# 192972     2021         4        A       골목상권  2111090  강일동주민센터  CS300016
# 192973     2021         4        A       골목상권  2111090  강일동주민센터  CS300018
# 192974     2021         4        A       골목상권  2111090  강일동주민센터  CS300020
# 192975     2021         4        A       골목상권  2111090  강일동주민센터  CS300021
# 192976     2021         4        A       골목상권  2111090  강일동주민센터  CS300022
#
#        서비스_업종_코드_명   분기당_매출_금액  분기당_매출_건수  ...  연령대_60_이상_매출_건수  점포수  \
# ...

# %%
district_merge.drop(district_merge.filter(regex='_y$').columns, axis=1, inplace=True)   #겹치는 컬럼 삭제

# %%
district_merge       #가장 데이터가 많은 상태. 구,분기별로 그룹화하지 않은 상태.
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  상권_코드_명 서비스_업종_코드  \
# 0          2021         1        A       골목상권  2110001   이북5도청사  CS100001
# 1          2021         1        A       골목상권  2110001   이북5도청사  CS100005
# 2          2021         1        A       골목상권  2110001   이북5도청사  CS100008
# 3          2021         1        A       골목상권  2110001   이북5도청사  CS100009
# 4          2021         1        A       골목상권  2110001   이북5도청사  CS100010
# ...         ...       ...      ...        ...      ...      ...       ...
# 192972     2021         4        A       골목상권  2111090  강일동주민센터  CS300016
# 192973     2021         4        A       골목상권  2111090  강일동주민센터  CS300018
# 192974     2021         4        A       골목상권  2111090  강일동주민센터  CS300020
# 192975     2021         4        A       골목상권  2111090  강일동주민센터  CS300021
# 192976     2021         4        A       골목상권  2111090  강일동주민센터  CS300022
#
#        서비스_업종_코드_명   분기당_매출_금액  분기당_매출_건수  ...  연령대_30_매출_건수  연령대_40_매출_건수  \
# ...

# %%
col_concat.to_excel('../../../Downloads/merge_상관분석_상권영역/전처리_상관분석서비스_2021.xlsx' )

# %%
gdf = district_merge.groupby(['시군구', '기준_분기_코드']).분기당_매출_건수.agg([np.count_nonzero, np.mean, np.sum])
gdf
# Out:
#               count_nonzero          mean        sum
# 시군구 기준_분기_코드
# 강남구 1                  2281  50957.551512  116234175
#     2                  2296  58491.459059  134296390
#     3                  2290  56471.690393  129320171
#     4                  2276  57551.171793  130986467
# 강동구 1                  2010  42347.295025   85118063
# ...                     ...           ...        ...
# 중구  4                   888  43219.283784   38378724
# 중랑구 1                  2299  36283.618530   83416039
#     2                  2296  41678.106272   95692932
#     3                  2300  42587.190000   97950537
#     4                  2265  40405.444150   91518331
#
# [100 rows x 3 columns]

# %%
district_merge.head(2)
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드 상권_코드_명 서비스_업종_코드  \
# 0     2021         1        A       골목상권  2110001  이북5도청사  CS100001
# 1     2021         1        A       골목상권  2110001  이북5도청사  CS100005
#
#   서비스_업종_코드_명   분기당_매출_금액  분기당_매출_건수  ...  연령대_30_매출_건수  연령대_40_매출_건수  \
# 0       한식음식점  1245854151      39079  ...          3180          6192
# 1         제과점   121486282      14059  ...          2147          3410
#
#    연령대_50_매출_건수  연령대_60_이상_매출_건수  점포수  엑스좌표_값  와이좌표_값  시군구_코드    행정동_코드  시군구
# 0         11463            11649   58  196193  456641   11110  11110560  종로구
# 1          3668             2378    3  196193  456641   11110  11110560  종로구
#
# [2 rows x 85 columns]

# %%
district_merge.columns
# Out:
# Index(['기준_년_코드', '기준_분기_코드', '상권_구분_코드', '상권_구분_코드_명', '상권_코드', '상권_코드_명',
#        '서비스_업종_코드', '서비스_업종_코드_명', '분기당_매출_금액', '분기당_매출_건수', '주중_매출_비율',
#        '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
#        '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
#        '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
#        '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
#        '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
#        '연령대_50_매출_비율', '연령대_60_이상_매출_비율', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#        '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액', '금요일_매출_금액', '토요일_매출_금액',
#        '일요일_매출_금액', '시간대_00~06_매출_금액', '시간대_06~11_매출_금액', '시간대_11~14_매출_금액',
#        '시간대_14~17_매출_금액', '시간대_17~21_매출_금액', '시간대_21~24_매출_금액', '남성_매출_금액',
#        '여성_매출_금액', '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
#        '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
# ...

# %%
group = district_merge.groupby(['기준_년_코드', '시군구', '기준_분기_코드'])
group_sum = group['분기당_매출_금액', '분기당_매출_건수', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액', 
      '화요일_매출_금액', '수요일_매출_금액', '목요일_매출_금액',  '금요일_매출_금액','토요일_매출_금액', 
      '일요일_매출_금액', '시간대_00~06_매출_금액','시간대_06~11_매출_금액',  '시간대_11~14_매출_금액', 
      '시간대_14~17_매출_금액', '시간대_17~21_매출_금액',  '시간대_21~24_매출_금액', '남성_매출_금액', '여성_매출_금액', 
      '연령대_10_매출_금액', '연령대_20_매출_금액', '연령대_30_매출_금액',
       '연령대_40_매출_금액', '연령대_50_매출_금액', '연령대_60_이상_매출_금액', '주중_매출_건수',
       '주말_매출_건수', '월요일_매출_건수', '화요일_매출_건수', '수요일_매출_건수', '목요일_매출_건수',
       '금요일_매출_건수', '토요일_매출_건수', '일요일_매출_건수', '시간대_건수~06_매출_건수',
       '시간대_건수~11_매출_건수', '시간대_건수~14_매출_건수', '시간대_건수~17_매출_건수',
       '시간대_건수~21_매출_건수', '시간대_건수~24_매출_건수', '남성_매출_건수', '여성_매출_건수',
       '연령대_10_매출_건수', '연령대_20_매출_건수', '연령대_30_매출_건수', '연령대_40_매출_건수',
       '연령대_50_매출_건수', '연령대_60_이상_매출_건수', '점포수'].sum()
group_sum
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6136\1322884270.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_sum = group['분기당_매출_금액', '분기당_매출_건수', '주중_매출_금액', '주말_매출_금액', '월요일_매출_금액',
#                           분기당_매출_금액  분기당_매출_건수       주중_매출_금액      주말_매출_금액  \
# 기준_년_코드 시군구 기준_분기_코드
# 2021    강남구 1         3845283427221  116234175  3009794802335  835488624886
#             2         4252502774950  134296390  3320553264853  931949510097
#             3         3996331475462  129320171  3106787415817  889544059645
#             4         4375687429272  130986467  3424213638093  951473791179
#         강동구 1         1853656172906   85118063  1396691033307  456965139599
# ...                             ...        ...            ...           ...
#         중구  4          974379910339   38378724   757194280174  217185630165
# ...

# %%
group_radius =  group['주중_매출_비율',
       '주말_매출_비율', '월요일_매출_비율', '화요일_매출_비율', '수요일_매출_비율', '목요일_매출_비율',
       '금요일_매출_비율', '토요일_매출_비율', '일요일_매출_비율', '시간대_00~06_매출_비율',
       '시간대_06~11_매출_비율', '시간대_11~14_매출_비율', '시간대_14~17_매출_비율',
       '시간대_17~21_매출_비율', '시간대_21~24_매출_비율', '남성_매출_비율', '여성_매출_비율',
       '연령대_10_매출_비율', '연령대_20_매출_비율', '연령대_30_매출_비율', '연령대_40_매출_비율',
       '연령대_50_매출_비율', '연령대_60_이상_매출_비율'].mean()
group_radius
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6136\2601992880.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   group_radius =  group['주중_매출_비율',
#                        주중_매출_비율   주말_매출_비율  월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  \
# 기준_년_코드 시군구 기준_분기_코드
# 2021    강남구 1         80.218325  19.876370  15.872863  17.135905  17.255590
#             2         80.382404  19.710801  15.613676  16.513066  15.128484
#             3         80.326201  19.774236  14.951965  14.911354  15.909607
#             4         80.406854  19.678383  14.250000  16.018014  15.899824
#         강동구 1         75.417910  24.681592  15.101493  15.659701  16.390547
# ...                         ...        ...        ...        ...        ...
#         중구  4         77.894144  22.191441  14.237613  15.015766  16.750000
#         중랑구 1         74.181383  25.921270  15.863854  14.786429  15.789474
# ...

# %%
col_concat = pd.concat([group_sum, group_radius ], axis = 1)
col_concat
# Out:
#                        주중_매출_비율   주말_매출_비율  월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  \
# 기준_년_코드 시군구 기준_분기_코드
# 2021    강남구 1         80.218325  19.876370  15.872863  17.135905  17.255590
#             2         80.382404  19.710801  15.613676  16.513066  15.128484
#             3         80.326201  19.774236  14.951965  14.911354  15.909607
#             4         80.406854  19.678383  14.250000  16.018014  15.899824
#         강동구 1         75.417910  24.681592  15.101493  15.659701  16.390547
# ...                         ...        ...        ...        ...        ...
#         중구  4         77.894144  22.191441  14.237613  15.015766  16.750000
#         중랑구 1         74.181383  25.921270  15.863854  14.786429  15.789474
#             2         74.702526  25.401132  15.263066  14.639808  15.375871
#             3         75.104348  24.990435  15.676522  13.536522  14.513043
#             4         75.509051  24.585430  14.364238  14.947903  14.471082
#
# ...

# %%
col_concat
# Out:
#                        주중_매출_비율   주말_매출_비율  월요일_매출_비율  화요일_매출_비율  수요일_매출_비율  \
# 기준_년_코드 시군구 기준_분기_코드
# 2021    강남구 1         80.218325  19.876370  15.872863  17.135905  17.255590
#             2         80.382404  19.710801  15.613676  16.513066  15.128484
#             3         80.326201  19.774236  14.951965  14.911354  15.909607
#             4         80.406854  19.678383  14.250000  16.018014  15.899824
#         강동구 1         75.417910  24.681592  15.101493  15.659701  16.390547
# ...                         ...        ...        ...        ...        ...
#         중구  4         77.894144  22.191441  14.237613  15.015766  16.750000
#         중랑구 1         74.181383  25.921270  15.863854  14.786429  15.789474
#             2         74.702526  25.401132  15.263066  14.639808  15.375871
#             3         75.104348  24.990435  15.676522  13.536522  14.513043
#             4         75.509051  24.585430  14.364238  14.947903  14.471082
#
# ...

# %%
#col_concat.to_excel('../../../Downloads/월별서울시상관분석서비스_전처리/preprocessing_상관분석서비스_2021.xlsx' )   
# 서울시_우리마을가게_상권분석서비스(신_상권배후지_추정매출)_2017년.csv에 구, 분기별로 금액,건수 등은 sum, 비율은 mean처리하여 groupby
