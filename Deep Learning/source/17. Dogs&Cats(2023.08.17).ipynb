# %% [markdown]
# # 컴퓨터 비전을 위한 딥러닝
# **google colab에서 실행함!!**
#
# #### 참고자료
# * <케라스 창시자에게 배우는 딥러닝 1판> 도서의 코드 저장소
#     * https://github.com/rickiepark/deep-learning-with-python-notebooks/blob/master/5.2-using-convnets-with-small-datasets.ipynb
# * <케라스 창시자에게 배우는 딥러닝 2판> 도서의 코드 저장소
#     * https://github.com/rickiepark/deep-learning-with-python-2nd
# * 캐글 Dogs vs Cats
#     * https://www.kaggle.com/c/dogs-vs-cats/data

# %% [markdown]
# ## 합성곱 신경망 소개

# %% [markdown]
# **간단한 컨브넷 만들기**

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# **모델의 `summary()` 메서드 출력**

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 10)                11530
#
# =================================================================
# Total params: 104202 (407.04 KB)
# Trainable params: 104202 (407.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **MNIST 이미지에서 컨브넷 훈련하기**

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(optimizer="rmsprop",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 33s 34ms/step - loss: 0.1581 - accuracy: 0.9501
# Epoch 2/5
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0440 - accuracy: 0.9863
# Epoch 3/5
# 938/938 [==============================] - 33s 35ms/step - loss: 0.0314 - accuracy: 0.9902
# Epoch 4/5
# 938/938 [==============================] - 33s 36ms/step - loss: 0.0230 - accuracy: 0.9930
# Epoch 5/5
# 938/938 [==============================] - 32s 34ms/step - loss: 0.0179 - accuracy: 0.9944

# %% [markdown]
# **컨브넷 평가하기**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0245 - accuracy: 0.9918
# 테스트 정확도: 0.992

# %% [markdown]
# ### 합성곱 연산

# %% [markdown]
# #### 경계 문제와 패딩 이해하기

# %% [markdown]
# #### 합성곱 스트라이등 이해하기

# %% [markdown]
# ### 최대 풀링 연산

# %% [markdown]
# **최대 풀링 층이 빠진 잘못된 구조의 컨브넷**

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 22, 22, 128)       73856
#
#  flatten_1 (Flatten)         (None, 61952)             0
#
#  dense_1 (Dense)             (None, 10)                619530
#
# =================================================================
# Total params: 712202 (2.72 MB)
# Trainable params: 712202 (2.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 소규모 데이터셋에서 밑바닥부터 컨브넷 훈련하기

# %% [markdown]
# ### 작은 데이터셋 문제에서 딥러닝의 타당성

# %% [markdown]
# ### 데이터 내려받기

# %% [markdown]
# 캐글에서 dogs-vs-cats 데이터셋을 다운로드하려면 캐글에 가입해야 한 후 생성한 API 키를 사용해야 합니다. 이런 과정이 번거롭다면 다음 명령으로 구글 드라이브에서 직접 다운로드할 수 있습니다.
#
# ```python
# import gdown
# gdown.download(id='18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd', output='dogs-vs-cats.zip')
# ```
#
# 그다음 아래 3개의 코드 셀을 건너 뛰고 바로 `unzip` 명령을 실행하세요.

# %%
#   !pip install gdown

# %%
import gdown
gdown.download(id='18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd', output='dogs-vs-cats.zip')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18uC7WTuEXKJDDxbj-Jq6EjzpFrgE7IAd
# To: /content/dogs-vs-cats.zip
# 100%|██████████| 852M/852M [00:14<00:00, 59.5MB/s]
# 'dogs-vs-cats.zip'

# %%
# kaggle.json 파일을 업로드하세요.
# from google.colab import files
# files.upload()

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
#  98% 798M/812M [00:04<00:00, 186MB/s]
# 100% 812M/812M [00:04<00:00, 174MB/s]

# %%
# !unzip -qq dogs-vs-cats.zip
# !unzip -qq train.zip

# %% [markdown]
# **이미지를 훈련, 검증, 테스트 디렉토리로 복사하기**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# ### 모델 만들기

# %% [markdown]
# **강아지 vs. 고양이 분류를 위한 소규모 컨브넷 만들기**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 256)         590080
#
#  flatten_2 (Flatten)         (None, 12544)             0
#
#  dense_2 (Dense)             (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **모델 훈련 설정하기**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# **`image_dataset_from_directory`를 사용하여 이미지 읽기**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **`Dataset`이 반환하는 데이터와 레이블 크기 확인하기**

# %%
for data_batch, labels_batch in train_dataset:
    print("데이터 배치 크기:", data_batch.shape)
    print("레이블 배치 크기:", labels_batch.shape)
    break
# Out:
# 데이터 배치 크기: (32, 180, 180, 3)
# 레이블 배치 크기: (32,)

# %% [markdown]
# **`Dataset`을 사용해 모델 훈련하기**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 9s 94ms/step - loss: 0.6960 - accuracy: 0.5345 - val_loss: 0.6882 - val_accuracy: 0.5390
# Epoch 2/30
# 63/63 [==============================] - 5s 69ms/step - loss: 0.6946 - accuracy: 0.5495 - val_loss: 0.6870 - val_accuracy: 0.5340
# Epoch 3/30
# 63/63 [==============================] - 6s 87ms/step - loss: 0.6767 - accuracy: 0.5815 - val_loss: 0.6653 - val_accuracy: 0.5930
# Epoch 4/30
# 63/63 [==============================] - 6s 98ms/step - loss: 0.6566 - accuracy: 0.6120 - val_loss: 0.6285 - val_accuracy: 0.6500
# Epoch 5/30
# 63/63 [==============================] - 7s 103ms/step - loss: 0.6223 - accuracy: 0.6580 - val_loss: 0.6453 - val_accuracy: 0.6470
# Epoch 6/30
# 63/63 [==============================] - 6s 88ms/step - loss: 0.5966 - accuracy: 0.6775 - val_loss: 0.5979 - val_accuracy: 0.6820
# Epoch 7/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.5608 - accuracy: 0.7200 - val_loss: 0.7257 - val_accuracy: 0.6280
# Epoch 8/30
# 63/63 [==============================] - 5s 80ms/step - loss: 0.5306 - accuracy: 0.7370 - val_loss: 0.5637 - val_accuracy: 0.7130
# Epoch 9/30
# 63/63 [==============================] - 4s 66ms/step - loss: 0.4892 - accuracy: 0.7550 - val_loss: 0.5908 - val_accuracy: 0.7210
# Epoch 10/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.4465 - accuracy: 0.7915 - val_loss: 0.5765 - val_accuracy: 0.7270
# Epoch 11/30
# 63/63 [==============================] - 5s 68ms/step - loss: 0.3918 - accuracy: 0.8230 - val_loss: 0.6688 - val_accuracy: 0.7280
# Epoch 12/30
# 63/63 [==============================] - 7s 104ms/step - loss: 0.3555 - accuracy: 0.8390 - val_loss: 0.5644 - val_accuracy: 0.7150
# Epoch 13/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2937 - accuracy: 0.8755 - val_loss: 0.7610 - val_accuracy: 0.6730
# Epoch 14/30
# 63/63 [==============================] - 4s 65ms/step - loss: 0.2459 - accuracy: 0.8985 - val_loss: 0.7476 - val_accuracy: 0.7320
# Epoch 15/30
# 63/63 [==============================] - 6s 84ms/step - loss: 0.1909 - accuracy: 0.9165 - val_loss: 0.9322 - val_accuracy: 0.7150
# Epoch 16/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1492 - accuracy: 0.9415 - val_loss: 0.8933 - val_accuracy: 0.7110
# Epoch 17/30
# 63/63 [==============================] - 6s 87ms/step - loss: 0.1132 - accuracy: 0.9580 - val_loss: 1.3140 - val_accuracy: 0.7120
# Epoch 18/30
# 63/63 [==============================] - 5s 73ms/step - loss: 0.0991 - accuracy: 0.9650 - val_loss: 1.0671 - val_accuracy: 0.7400
# Epoch 19/30
# 63/63 [==============================] - 4s 65ms/step - loss: 0.0663 - accuracy: 0.9745 - val_loss: 1.7880 - val_accuracy: 0.6850
# Epoch 20/30
# 63/63 [==============================] - 5s 78ms/step - loss: 0.0987 - accuracy: 0.9660 - val_loss: 1.3216 - val_accuracy: 0.7340
# Epoch 21/30
# 63/63 [==============================] - 4s 66ms/step - loss: 0.0682 - accuracy: 0.9770 - val_loss: 1.1459 - val_accuracy: 0.7310
# Epoch 22/30
# 63/63 [==============================] - 5s 83ms/step - loss: 0.0333 - accuracy: 0.9905 - val_loss: 1.3571 - val_accuracy: 0.7620
# Epoch 23/30
# 63/63 [==============================] - 4s 65ms/step - loss: 0.0590 - accuracy: 0.9805 - val_loss: 1.5391 - val_accuracy: 0.7460
# Epoch 24/30
# 63/63 [==============================] - 4s 67ms/step - loss: 0.0620 - accuracy: 0.9740 - val_loss: 1.3522 - val_accuracy: 0.7440
# Epoch 25/30
# 63/63 [==============================] - 6s 85ms/step - loss: 0.0353 - accuracy: 0.9885 - val_loss: 1.6069 - val_accuracy: 0.7490
# Epoch 26/30
# 63/63 [==============================] - 6s 86ms/step - loss: 0.0632 - accuracy: 0.9800 - val_loss: 1.3030 - val_accuracy: 0.7380
# Epoch 27/30
# 63/63 [==============================] - 4s 66ms/step - loss: 0.0256 - accuracy: 0.9915 - val_loss: 1.9217 - val_accuracy: 0.7100
# Epoch 28/30
# 63/63 [==============================] - 4s 65ms/step - loss: 0.0513 - accuracy: 0.9840 - val_loss: 1.6366 - val_accuracy: 0.7150
# Epoch 29/30
# 63/63 [==============================] - 5s 75ms/step - loss: 0.0449 - accuracy: 0.9895 - val_loss: 1.6807 - val_accuracy: 0.7380
# Epoch 30/30
# 63/63 [==============================] - 4s 66ms/step - loss: 0.0255 - accuracy: 0.9915 - val_loss: 2.0144 - val_accuracy: 0.7540

# %% [markdown]
# **훈련 정확도와 손실 그래프 그리기**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **테스트 세트에서 모델 평가하기**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 3s 36ms/step - loss: 0.5677 - accuracy: 0.7080
# 테스트 정확도: 0.708

# %% [markdown]
# ### 데이터 증식 사용하기

# %% [markdown]
# **컨브넷에 추가할 데이터 증식 단계 정의하기**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **랜덤하게 증식된 훈련 이미지 출력하기**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **이미지 증식과 드롭아웃을 포함한 컨브넷 만들기**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **규제를 추가한 컨브넷 훈련하기**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 8s 70ms/step - loss: 0.6958 - accuracy: 0.4980 - val_loss: 0.6922 - val_accuracy: 0.5010
# Epoch 2/100
# 63/63 [==============================] - 6s 86ms/step - loss: 0.6926 - accuracy: 0.5370 - val_loss: 0.6903 - val_accuracy: 0.5040
# Epoch 3/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.6851 - accuracy: 0.5540 - val_loss: 0.6718 - val_accuracy: 0.5260
# Epoch 4/100
# 63/63 [==============================] - 5s 75ms/step - loss: 0.6617 - accuracy: 0.6205 - val_loss: 0.6381 - val_accuracy: 0.6390
# Epoch 5/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.6363 - accuracy: 0.6415 - val_loss: 0.6158 - val_accuracy: 0.6480
# Epoch 6/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.6257 - accuracy: 0.6630 - val_loss: 0.7689 - val_accuracy: 0.5810
# Epoch 7/100
# 63/63 [==============================] - 5s 67ms/step - loss: 0.6063 - accuracy: 0.6630 - val_loss: 0.7366 - val_accuracy: 0.6250
# Epoch 8/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.6112 - accuracy: 0.6655 - val_loss: 0.5770 - val_accuracy: 0.7040
# Epoch 9/100
# 63/63 [==============================] - 5s 76ms/step - loss: 0.5970 - accuracy: 0.6955 - val_loss: 0.5801 - val_accuracy: 0.6860
# Epoch 10/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.5718 - accuracy: 0.7120 - val_loss: 0.5598 - val_accuracy: 0.7170
# Epoch 11/100
# 63/63 [==============================] - 7s 102ms/step - loss: 0.5835 - accuracy: 0.6930 - val_loss: 0.5511 - val_accuracy: 0.7130
# Epoch 12/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.5643 - accuracy: 0.7055 - val_loss: 0.6493 - val_accuracy: 0.6560
# Epoch 13/100
# 63/63 [==============================] - 5s 83ms/step - loss: 0.5463 - accuracy: 0.7285 - val_loss: 0.5501 - val_accuracy: 0.7250
# Epoch 14/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.5314 - accuracy: 0.7455 - val_loss: 0.5302 - val_accuracy: 0.7460
# Epoch 15/100
# 63/63 [==============================] - 6s 89ms/step - loss: 0.5400 - accuracy: 0.7335 - val_loss: 0.5194 - val_accuracy: 0.7340
# Epoch 16/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.5328 - accuracy: 0.7365 - val_loss: 0.5103 - val_accuracy: 0.7560
# Epoch 17/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.5209 - accuracy: 0.7375 - val_loss: 0.6407 - val_accuracy: 0.6510
# Epoch 18/100
# 63/63 [==============================] - 6s 88ms/step - loss: 0.5106 - accuracy: 0.7500 - val_loss: 0.5523 - val_accuracy: 0.7360
# Epoch 19/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.5111 - accuracy: 0.7555 - val_loss: 0.5033 - val_accuracy: 0.7620
# Epoch 20/100
# 63/63 [==============================] - 5s 72ms/step - loss: 0.5057 - accuracy: 0.7510 - val_loss: 0.4892 - val_accuracy: 0.7700
# Epoch 21/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.4913 - accuracy: 0.7690 - val_loss: 0.4872 - val_accuracy: 0.7680
# Epoch 22/100
# 63/63 [==============================] - 5s 67ms/step - loss: 0.4637 - accuracy: 0.7740 - val_loss: 0.4784 - val_accuracy: 0.7780
# Epoch 23/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.4685 - accuracy: 0.7840 - val_loss: 0.5168 - val_accuracy: 0.7410
# Epoch 24/100
# 63/63 [==============================] - 4s 66ms/step - loss: 0.4563 - accuracy: 0.7845 - val_loss: 0.5942 - val_accuracy: 0.7240
# Epoch 25/100
# 63/63 [==============================] - 4s 66ms/step - loss: 0.4518 - accuracy: 0.7815 - val_loss: 0.5057 - val_accuracy: 0.7560
# Epoch 26/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.4215 - accuracy: 0.7965 - val_loss: 0.4548 - val_accuracy: 0.8060
# Epoch 27/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.4382 - accuracy: 0.8020 - val_loss: 0.4632 - val_accuracy: 0.7890
# Epoch 28/100
# 63/63 [==============================] - 6s 88ms/step - loss: 0.4080 - accuracy: 0.8105 - val_loss: 0.4656 - val_accuracy: 0.7730
# Epoch 29/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.4182 - accuracy: 0.8085 - val_loss: 0.4521 - val_accuracy: 0.7950
# Epoch 30/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.4165 - accuracy: 0.8160 - val_loss: 0.5815 - val_accuracy: 0.7530
# Epoch 31/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.4005 - accuracy: 0.8180 - val_loss: 0.4088 - val_accuracy: 0.8250
# Epoch 32/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.3667 - accuracy: 0.8335 - val_loss: 0.4942 - val_accuracy: 0.8000
# Epoch 33/100
# 63/63 [==============================] - 5s 76ms/step - loss: 0.3880 - accuracy: 0.8170 - val_loss: 0.5871 - val_accuracy: 0.7640
# Epoch 34/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.3839 - accuracy: 0.8365 - val_loss: 0.4813 - val_accuracy: 0.8150
# Epoch 35/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.3703 - accuracy: 0.8360 - val_loss: 0.4913 - val_accuracy: 0.7960
# Epoch 36/100
# 63/63 [==============================] - 5s 82ms/step - loss: 0.3524 - accuracy: 0.8495 - val_loss: 0.4532 - val_accuracy: 0.7930
# Epoch 37/100
# 63/63 [==============================] - 6s 89ms/step - loss: 0.3656 - accuracy: 0.8365 - val_loss: 0.4420 - val_accuracy: 0.8300
# Epoch 38/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.3278 - accuracy: 0.8600 - val_loss: 0.5433 - val_accuracy: 0.7980
# Epoch 39/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.3351 - accuracy: 0.8670 - val_loss: 0.4947 - val_accuracy: 0.8340
# Epoch 40/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.3420 - accuracy: 0.8550 - val_loss: 0.4603 - val_accuracy: 0.8140
# Epoch 41/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.3196 - accuracy: 0.8680 - val_loss: 0.4830 - val_accuracy: 0.7900
# Epoch 42/100
# 63/63 [==============================] - 6s 89ms/step - loss: 0.3031 - accuracy: 0.8700 - val_loss: 0.5588 - val_accuracy: 0.7720
# Epoch 43/100
# 63/63 [==============================] - 4s 66ms/step - loss: 0.3182 - accuracy: 0.8680 - val_loss: 0.5955 - val_accuracy: 0.7970
# Epoch 44/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.3013 - accuracy: 0.8700 - val_loss: 0.4320 - val_accuracy: 0.8230
# Epoch 45/100
# 63/63 [==============================] - 6s 89ms/step - loss: 0.2964 - accuracy: 0.8685 - val_loss: 0.5765 - val_accuracy: 0.7820
# Epoch 46/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.2969 - accuracy: 0.8705 - val_loss: 0.3897 - val_accuracy: 0.8380
# Epoch 47/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.2772 - accuracy: 0.8825 - val_loss: 0.4166 - val_accuracy: 0.8340
# Epoch 48/100
# 63/63 [==============================] - 6s 82ms/step - loss: 0.2847 - accuracy: 0.8775 - val_loss: 0.4884 - val_accuracy: 0.8320
# Epoch 49/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.2875 - accuracy: 0.8920 - val_loss: 0.5054 - val_accuracy: 0.8170
# Epoch 50/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.2516 - accuracy: 0.8955 - val_loss: 0.4358 - val_accuracy: 0.8450
# Epoch 51/100
# 63/63 [==============================] - 6s 82ms/step - loss: 0.2633 - accuracy: 0.8825 - val_loss: 0.6770 - val_accuracy: 0.7900
# Epoch 52/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2399 - accuracy: 0.8960 - val_loss: 0.9549 - val_accuracy: 0.7520
# Epoch 53/100
# 63/63 [==============================] - 5s 84ms/step - loss: 0.2448 - accuracy: 0.9040 - val_loss: 0.4894 - val_accuracy: 0.8350
# Epoch 54/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.2589 - accuracy: 0.8940 - val_loss: 0.5452 - val_accuracy: 0.8150
# Epoch 55/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.2276 - accuracy: 0.9140 - val_loss: 0.6531 - val_accuracy: 0.8200
# Epoch 56/100
# 63/63 [==============================] - 6s 86ms/step - loss: 0.2613 - accuracy: 0.8955 - val_loss: 0.3827 - val_accuracy: 0.8530
# Epoch 57/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.2286 - accuracy: 0.9105 - val_loss: 0.4926 - val_accuracy: 0.8440
# Epoch 58/100
# 63/63 [==============================] - 6s 89ms/step - loss: 0.2267 - accuracy: 0.9140 - val_loss: 0.4293 - val_accuracy: 0.8400
# Epoch 59/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2228 - accuracy: 0.9120 - val_loss: 0.5469 - val_accuracy: 0.8380
# Epoch 60/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2381 - accuracy: 0.9065 - val_loss: 0.4570 - val_accuracy: 0.8470
# Epoch 61/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.2332 - accuracy: 0.9120 - val_loss: 0.5718 - val_accuracy: 0.8240
# Epoch 62/100
# 63/63 [==============================] - 5s 83ms/step - loss: 0.2267 - accuracy: 0.9185 - val_loss: 0.5528 - val_accuracy: 0.8390
# Epoch 63/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.1919 - accuracy: 0.9225 - val_loss: 0.4420 - val_accuracy: 0.8500
# Epoch 64/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2086 - accuracy: 0.9145 - val_loss: 0.4674 - val_accuracy: 0.8390
# Epoch 65/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.1968 - accuracy: 0.9230 - val_loss: 0.5982 - val_accuracy: 0.8290
# Epoch 66/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.1904 - accuracy: 0.9290 - val_loss: 0.5685 - val_accuracy: 0.8440
# Epoch 67/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.2188 - accuracy: 0.9240 - val_loss: 0.5140 - val_accuracy: 0.8530
# Epoch 68/100
# 63/63 [==============================] - 5s 82ms/step - loss: 0.2146 - accuracy: 0.9215 - val_loss: 0.5264 - val_accuracy: 0.8220
# Epoch 69/100
# 63/63 [==============================] - 5s 67ms/step - loss: 0.2098 - accuracy: 0.9160 - val_loss: 0.4991 - val_accuracy: 0.8430
# Epoch 70/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.2226 - accuracy: 0.9170 - val_loss: 0.4580 - val_accuracy: 0.8320
# Epoch 71/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.2056 - accuracy: 0.9230 - val_loss: 0.4644 - val_accuracy: 0.8420
# Epoch 72/100
# 63/63 [==============================] - 6s 90ms/step - loss: 0.1724 - accuracy: 0.9325 - val_loss: 1.0350 - val_accuracy: 0.7950
# Epoch 73/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.2034 - accuracy: 0.9230 - val_loss: 0.4277 - val_accuracy: 0.8460
# Epoch 74/100
# 63/63 [==============================] - 6s 86ms/step - loss: 0.1872 - accuracy: 0.9260 - val_loss: 0.4908 - val_accuracy: 0.8550
# Epoch 75/100
# 63/63 [==============================] - 5s 69ms/step - loss: 0.1704 - accuracy: 0.9335 - val_loss: 0.6221 - val_accuracy: 0.8390
# Epoch 76/100
# 63/63 [==============================] - 6s 90ms/step - loss: 0.1717 - accuracy: 0.9340 - val_loss: 0.5365 - val_accuracy: 0.8470
# Epoch 77/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.1805 - accuracy: 0.9275 - val_loss: 0.6808 - val_accuracy: 0.8310
# Epoch 78/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.1509 - accuracy: 0.9430 - val_loss: 0.6912 - val_accuracy: 0.8610
# Epoch 79/100
# 63/63 [==============================] - 6s 86ms/step - loss: 0.1976 - accuracy: 0.9310 - val_loss: 0.6495 - val_accuracy: 0.8400
# Epoch 80/100
# 63/63 [==============================] - 6s 84ms/step - loss: 0.1806 - accuracy: 0.9320 - val_loss: 0.7635 - val_accuracy: 0.8140
# Epoch 81/100
# 63/63 [==============================] - 6s 89ms/step - loss: 0.1643 - accuracy: 0.9400 - val_loss: 0.5960 - val_accuracy: 0.8330
# Epoch 82/100
# 63/63 [==============================] - 8s 107ms/step - loss: 0.2111 - accuracy: 0.9370 - val_loss: 0.5944 - val_accuracy: 0.8450
# Epoch 83/100
# 63/63 [==============================] - 5s 82ms/step - loss: 0.1525 - accuracy: 0.9420 - val_loss: 0.8041 - val_accuracy: 0.8300
# Epoch 84/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1808 - accuracy: 0.9255 - val_loss: 0.6556 - val_accuracy: 0.8540
# Epoch 85/100
# 63/63 [==============================] - 6s 89ms/step - loss: 0.1393 - accuracy: 0.9455 - val_loss: 0.7049 - val_accuracy: 0.8520
# Epoch 86/100
# 63/63 [==============================] - 5s 67ms/step - loss: 0.1818 - accuracy: 0.9310 - val_loss: 0.7142 - val_accuracy: 0.8350
# Epoch 87/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.1587 - accuracy: 0.9435 - val_loss: 0.7293 - val_accuracy: 0.8450
# Epoch 88/100
# 63/63 [==============================] - 6s 86ms/step - loss: 0.1543 - accuracy: 0.9405 - val_loss: 0.5282 - val_accuracy: 0.8520
# Epoch 89/100
# 63/63 [==============================] - 4s 68ms/step - loss: 0.1474 - accuracy: 0.9460 - val_loss: 0.7574 - val_accuracy: 0.8600
# Epoch 90/100
# 63/63 [==============================] - 5s 82ms/step - loss: 0.1573 - accuracy: 0.9415 - val_loss: 3.0952 - val_accuracy: 0.7070
# Epoch 91/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1638 - accuracy: 0.9510 - val_loss: 0.6627 - val_accuracy: 0.8560
# Epoch 92/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.1449 - accuracy: 0.9450 - val_loss: 0.7248 - val_accuracy: 0.8470
# Epoch 93/100
# 63/63 [==============================] - 5s 82ms/step - loss: 0.1585 - accuracy: 0.9390 - val_loss: 0.9226 - val_accuracy: 0.8550
# Epoch 94/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.1537 - accuracy: 0.9435 - val_loss: 0.6344 - val_accuracy: 0.8450
# Epoch 95/100
# 63/63 [==============================] - 6s 91ms/step - loss: 0.1316 - accuracy: 0.9485 - val_loss: 1.5645 - val_accuracy: 0.7610
# Epoch 96/100
# 63/63 [==============================] - 4s 67ms/step - loss: 0.1703 - accuracy: 0.9450 - val_loss: 0.9289 - val_accuracy: 0.8500
# Epoch 97/100
# 63/63 [==============================] - 6s 85ms/step - loss: 0.1452 - accuracy: 0.9490 - val_loss: 0.7113 - val_accuracy: 0.8620
# Epoch 98/100
# 63/63 [==============================] - 5s 68ms/step - loss: 0.1672 - accuracy: 0.9435 - val_loss: 0.7613 - val_accuracy: 0.8600
# Epoch 99/100
# 63/63 [==============================] - 6s 87ms/step - loss: 0.1410 - accuracy: 0.9495 - val_loss: 0.6621 - val_accuracy: 0.8710
# Epoch 100/100
# 63/63 [==============================] - 5s 70ms/step - loss: 0.1441 - accuracy: 0.9480 - val_loss: 0.6249 - val_accuracy: 0.8640

# %% [markdown]
# **테스트 세트에서 모델 훈련하기**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 4s 53ms/step - loss: 0.4662 - accuracy: 0.8280
# 테스트 정확도: 0.828

# %% [markdown]
# ## 사전 훈련된 모델 활용하기

# %% [markdown]
# ### 사전 훈련된 모델을 사용한 특성 추출

# %% [markdown]
# **VGG16 합성곱 기반 층 만들기**

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 데이터 증식을 사용하지 않는 빠른 특성 추출

# %% [markdown]
# **VGG16 특성과 해당 레이블 추출하기**

# %%
import numpy as np

def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
train_features.shape
# Out:
# (2000, 5, 5, 512)

# %% [markdown]
# **밀집 연결 분류기 정의하고 훈련하기**

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
      filepath="feature_extraction.keras",
      save_best_only=True,
      monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 2s 10ms/step - loss: 23.4865 - accuracy: 0.9200 - val_loss: 5.3934 - val_accuracy: 0.9660
# Epoch 2/20
# 63/63 [==============================] - 0s 5ms/step - loss: 3.5043 - accuracy: 0.9760 - val_loss: 12.1187 - val_accuracy: 0.9370
# Epoch 3/20
# 63/63 [==============================] - 0s 6ms/step - loss: 2.1154 - accuracy: 0.9865 - val_loss: 4.5314 - val_accuracy: 0.9710
# Epoch 4/20
# 63/63 [==============================] - 0s 7ms/step - loss: 1.8637 - accuracy: 0.9855 - val_loss: 4.4542 - val_accuracy: 0.9750
# Epoch 5/20
# 63/63 [==============================] - 0s 5ms/step - loss: 1.4951 - accuracy: 0.9905 - val_loss: 6.3071 - val_accuracy: 0.9700
# Epoch 6/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.6177 - accuracy: 0.9930 - val_loss: 8.5176 - val_accuracy: 0.9690
# Epoch 7/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.2554 - accuracy: 0.9980 - val_loss: 4.8951 - val_accuracy: 0.9740
# Epoch 8/20
# 63/63 [==============================] - 0s 5ms/step - loss: 1.1271 - accuracy: 0.9935 - val_loss: 6.5310 - val_accuracy: 0.9710
# Epoch 9/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.2007 - accuracy: 0.9985 - val_loss: 5.3059 - val_accuracy: 0.9750
# Epoch 10/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.6281 - accuracy: 0.9960 - val_loss: 5.8339 - val_accuracy: 0.9740
# Epoch 11/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1713 - accuracy: 0.9975 - val_loss: 5.5412 - val_accuracy: 0.9740
# Epoch 12/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.1723 - accuracy: 0.9985 - val_loss: 6.0541 - val_accuracy: 0.9720
# Epoch 13/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9995 - val_loss: 5.4872 - val_accuracy: 0.9720
# Epoch 14/20
# 63/63 [==============================] - 0s 5ms/step - loss: 0.3746 - accuracy: 0.9965 - val_loss: 5.0154 - val_accuracy: 0.9700
# Epoch 15/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.2077 - accuracy: 0.9965 - val_loss: 6.2871 - val_accuracy: 0.9740
# Epoch 16/20
# 63/63 [==============================] - 0s 6ms/step - loss: 0.3497 - accuracy: 0.9985 - val_loss: 3.9029 - val_accuracy: 0.9780
# Epoch 17/20
# 63/63 [==============================] - 0s 6ms/step - loss: 6.8305e-18 - accuracy: 1.0000 - val_loss: 3.9029 - val_accuracy: 0.9780
# Epoch 18/20
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1031 - accuracy: 0.9985 - val_loss: 4.6597 - val_accuracy: 0.9730
# Epoch 19/20
# 63/63 [==============================] - 0s 7ms/step - loss: 3.4283e-13 - accuracy: 1.0000 - val_loss: 4.6597 - val_accuracy: 0.9730
# Epoch 20/20
# 63/63 [==============================] - 0s 8ms/step - loss: 0.0378 - accuracy: 0.9985 - val_loss: 4.9406 - val_accuracy: 0.9740

# %% [markdown]
# **결과를 그래프로 나타내기**

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model(
    "feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features,test_labels)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 0s 3ms/step - loss: 6.7772 - accuracy: 0.9715
# 테스트 정확도: 0.971

# %% [markdown]
# #### 데이터 증식을 사용한 특성 추출

# %% [markdown]
# **VGG16 합성곱 기반 층을 만들고 동결하기**

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False

# %% [markdown]
# **동결하기 전과 후에 훈련 가능한 가중치 리스트를 출력하기**

# %%
conv_base.trainable = True
print("합성곱 기반 층을 동결하기 전의 훈련 가능한 가중치 개수:",
      len(conv_base.trainable_weights))
# Out:
# 합성곱 기반 층을 동결하기 전의 훈련 가능한 가중치 개수: 26

# %%
conv_base.trainable = False
print("합성곱 기반 층을 동결한 후의 훈련 가능한 가중치 개수:",
      len(conv_base.trainable_weights))
# Out:
# 합성곱 기반 층을 동결한 후의 훈련 가능한 가중치 개수: 0

# %% [markdown]
# **데이터 증식 단계와 밀집 분류기를 합성곱 기반 층에 추가하기**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 63/63 [==============================] - 12s 152ms/step - loss: 17.5213 - accuracy: 0.8910 - val_loss: 8.6929 - val_accuracy: 0.9530
# Epoch 2/50
# 63/63 [==============================] - 10s 152ms/step - loss: 7.3695 - accuracy: 0.9550 - val_loss: 4.9906 - val_accuracy: 0.9600
# Epoch 3/50
# 63/63 [==============================] - 12s 183ms/step - loss: 7.2892 - accuracy: 0.9470 - val_loss: 3.9203 - val_accuracy: 0.9670
# Epoch 4/50
# 63/63 [==============================] - 10s 150ms/step - loss: 5.3748 - accuracy: 0.9610 - val_loss: 3.5079 - val_accuracy: 0.9710
# Epoch 5/50
# 63/63 [==============================] - 11s 177ms/step - loss: 5.1218 - accuracy: 0.9620 - val_loss: 10.5563 - val_accuracy: 0.9500
# Epoch 6/50
# 63/63 [==============================] - 11s 177ms/step - loss: 3.7358 - accuracy: 0.9655 - val_loss: 4.5061 - val_accuracy: 0.9690
# Epoch 7/50
# 63/63 [==============================] - 9s 144ms/step - loss: 3.1667 - accuracy: 0.9695 - val_loss: 3.6264 - val_accuracy: 0.9790
# Epoch 8/50
# 63/63 [==============================] - 10s 145ms/step - loss: 2.2456 - accuracy: 0.9760 - val_loss: 5.0522 - val_accuracy: 0.9760
# Epoch 9/50
# 63/63 [==============================] - 9s 145ms/step - loss: 3.3243 - accuracy: 0.9695 - val_loss: 3.5850 - val_accuracy: 0.9800
# Epoch 10/50
# 63/63 [==============================] - 10s 148ms/step - loss: 2.3762 - accuracy: 0.9735 - val_loss: 3.6947 - val_accuracy: 0.9800
# Epoch 11/50
# 63/63 [==============================] - 12s 180ms/step - loss: 2.0812 - accuracy: 0.9810 - val_loss: 3.2288 - val_accuracy: 0.9810
# Epoch 12/50
# 63/63 [==============================] - 11s 152ms/step - loss: 1.6496 - accuracy: 0.9835 - val_loss: 9.1576 - val_accuracy: 0.9570
# Epoch 13/50
# 63/63 [==============================] - 12s 184ms/step - loss: 2.4481 - accuracy: 0.9765 - val_loss: 2.9874 - val_accuracy: 0.9800
# Epoch 14/50
# 63/63 [==============================] - 10s 148ms/step - loss: 2.1406 - accuracy: 0.9795 - val_loss: 3.2038 - val_accuracy: 0.9800
# Epoch 15/50
# 63/63 [==============================] - 10s 156ms/step - loss: 2.5298 - accuracy: 0.9750 - val_loss: 2.5543 - val_accuracy: 0.9800
# Epoch 16/50
# 63/63 [==============================] - 9s 146ms/step - loss: 1.8051 - accuracy: 0.9815 - val_loss: 2.9084 - val_accuracy: 0.9780
# Epoch 17/50
# 63/63 [==============================] - 10s 154ms/step - loss: 2.1161 - accuracy: 0.9765 - val_loss: 2.0737 - val_accuracy: 0.9830
# Epoch 18/50
# 63/63 [==============================] - 10s 144ms/step - loss: 1.4170 - accuracy: 0.9840 - val_loss: 4.4161 - val_accuracy: 0.9690
# Epoch 19/50
# 63/63 [==============================] - 9s 144ms/step - loss: 1.2556 - accuracy: 0.9825 - val_loss: 2.8873 - val_accuracy: 0.9800
# Epoch 20/50
# 63/63 [==============================] - 10s 150ms/step - loss: 0.9434 - accuracy: 0.9855 - val_loss: 2.4998 - val_accuracy: 0.9800
# Epoch 21/50
# 63/63 [==============================] - 9s 144ms/step - loss: 1.2643 - accuracy: 0.9840 - val_loss: 2.1714 - val_accuracy: 0.9830
# Epoch 22/50
# 63/63 [==============================] - 10s 144ms/step - loss: 1.5617 - accuracy: 0.9800 - val_loss: 2.2113 - val_accuracy: 0.9820
# Epoch 23/50
# 63/63 [==============================] - 11s 178ms/step - loss: 1.0050 - accuracy: 0.9840 - val_loss: 2.3056 - val_accuracy: 0.9800
# Epoch 24/50
# 63/63 [==============================] - 9s 146ms/step - loss: 0.7935 - accuracy: 0.9855 - val_loss: 3.3400 - val_accuracy: 0.9760
# Epoch 25/50
# 63/63 [==============================] - 10s 150ms/step - loss: 1.6795 - accuracy: 0.9775 - val_loss: 2.6628 - val_accuracy: 0.9790
# Epoch 26/50
# 63/63 [==============================] - 11s 177ms/step - loss: 1.2991 - accuracy: 0.9790 - val_loss: 2.2323 - val_accuracy: 0.9830
# Epoch 27/50
# 63/63 [==============================] - 11s 177ms/step - loss: 1.2965 - accuracy: 0.9800 - val_loss: 2.8874 - val_accuracy: 0.9720
# Epoch 28/50
# 63/63 [==============================] - 9s 145ms/step - loss: 1.0416 - accuracy: 0.9835 - val_loss: 3.7520 - val_accuracy: 0.9710
# Epoch 29/50
# 63/63 [==============================] - 10s 145ms/step - loss: 0.7474 - accuracy: 0.9880 - val_loss: 2.7229 - val_accuracy: 0.9780
# Epoch 30/50
# 63/63 [==============================] - 9s 145ms/step - loss: 0.5198 - accuracy: 0.9845 - val_loss: 2.5009 - val_accuracy: 0.9790
# Epoch 31/50
# 63/63 [==============================] - 10s 150ms/step - loss: 0.9749 - accuracy: 0.9850 - val_loss: 2.7834 - val_accuracy: 0.9780
# Epoch 32/50
# 63/63 [==============================] - 10s 149ms/step - loss: 0.9353 - accuracy: 0.9855 - val_loss: 2.0141 - val_accuracy: 0.9820
# Epoch 33/50
# 63/63 [==============================] - 9s 145ms/step - loss: 0.4864 - accuracy: 0.9910 - val_loss: 2.2100 - val_accuracy: 0.9830
# Epoch 34/50
# 63/63 [==============================] - 9s 145ms/step - loss: 1.0062 - accuracy: 0.9830 - val_loss: 2.5825 - val_accuracy: 0.9790
# Epoch 35/50
# 63/63 [==============================] - 9s 147ms/step - loss: 0.5360 - accuracy: 0.9890 - val_loss: 2.4159 - val_accuracy: 0.9800
# Epoch 36/50
# 63/63 [==============================] - 11s 177ms/step - loss: 0.6372 - accuracy: 0.9890 - val_loss: 2.4190 - val_accuracy: 0.9750
# Epoch 37/50
# 63/63 [==============================] - 9s 142ms/step - loss: 0.7826 - accuracy: 0.9860 - val_loss: 2.1104 - val_accuracy: 0.9780
# Epoch 38/50
# 63/63 [==============================] - 9s 147ms/step - loss: 0.6832 - accuracy: 0.9860 - val_loss: 2.3847 - val_accuracy: 0.9780
# Epoch 39/50
# 63/63 [==============================] - 10s 148ms/step - loss: 0.6731 - accuracy: 0.9845 - val_loss: 2.0956 - val_accuracy: 0.9800
# Epoch 40/50
# 63/63 [==============================] - 9s 147ms/step - loss: 0.6006 - accuracy: 0.9880 - val_loss: 2.4393 - val_accuracy: 0.9770
# Epoch 41/50
# 63/63 [==============================] - 11s 178ms/step - loss: 0.5431 - accuracy: 0.9885 - val_loss: 2.7689 - val_accuracy: 0.9750
# Epoch 42/50
# 63/63 [==============================] - 10s 154ms/step - loss: 0.4115 - accuracy: 0.9895 - val_loss: 1.9485 - val_accuracy: 0.9790
# Epoch 43/50
# 63/63 [==============================] - 10s 148ms/step - loss: 0.6219 - accuracy: 0.9895 - val_loss: 1.8966 - val_accuracy: 0.9820
# Epoch 44/50
# 63/63 [==============================] - 10s 148ms/step - loss: 0.6624 - accuracy: 0.9880 - val_loss: 2.2493 - val_accuracy: 0.9810
# Epoch 45/50
# 63/63 [==============================] - 9s 144ms/step - loss: 0.5175 - accuracy: 0.9880 - val_loss: 2.3405 - val_accuracy: 0.9810
# Epoch 46/50
# 63/63 [==============================] - 9s 144ms/step - loss: 0.2032 - accuracy: 0.9955 - val_loss: 2.1317 - val_accuracy: 0.9810
# Epoch 47/50
# 63/63 [==============================] - 10s 150ms/step - loss: 0.4599 - accuracy: 0.9890 - val_loss: 1.8179 - val_accuracy: 0.9860
# Epoch 48/50
# 63/63 [==============================] - 10s 153ms/step - loss: 0.5775 - accuracy: 0.9880 - val_loss: 1.9778 - val_accuracy: 0.9850
# Epoch 49/50
# 63/63 [==============================] - 12s 178ms/step - loss: 0.4729 - accuracy: 0.9900 - val_loss: 2.1312 - val_accuracy: 0.9770
# Epoch 50/50
# 63/63 [==============================] - 9s 144ms/step - loss: 0.6021 - accuracy: 0.9910 - val_loss: 2.1689 - val_accuracy: 0.9800

# %%
import matplotlib.pyplot as plt
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "bo", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **테스트 세트에서 모델 평가하기**

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 6s 91ms/step - loss: 2.2497 - accuracy: 0.9765
# 테스트 정확도: 0.976

# %% [markdown]
# ### 사전 훈련된 모델 미세 조정하기

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# **마지막에서 네 번째 층까지 모든 층 동결하기**

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %% [markdown]
# **모델 미세 조정하기**

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 14s 171ms/step - loss: 0.4787 - accuracy: 0.9885 - val_loss: 1.9611 - val_accuracy: 0.9780
# Epoch 2/30
# 63/63 [==============================] - 11s 167ms/step - loss: 0.4242 - accuracy: 0.9895 - val_loss: 1.9481 - val_accuracy: 0.9820
# Epoch 3/30
# 63/63 [==============================] - 11s 169ms/step - loss: 0.3662 - accuracy: 0.9930 - val_loss: 1.4984 - val_accuracy: 0.9840
# Epoch 4/30
# 63/63 [==============================] - 11s 163ms/step - loss: 0.3284 - accuracy: 0.9885 - val_loss: 2.3493 - val_accuracy: 0.9730
# Epoch 5/30
# 63/63 [==============================] - 11s 165ms/step - loss: 0.3785 - accuracy: 0.9890 - val_loss: 2.1263 - val_accuracy: 0.9770
# Epoch 6/30
# 63/63 [==============================] - 10s 159ms/step - loss: 0.1941 - accuracy: 0.9925 - val_loss: 2.1712 - val_accuracy: 0.9760
# Epoch 7/30
# 63/63 [==============================] - 11s 160ms/step - loss: 0.2369 - accuracy: 0.9920 - val_loss: 1.6105 - val_accuracy: 0.9820
# Epoch 8/30
# 63/63 [==============================] - 11s 164ms/step - loss: 0.1236 - accuracy: 0.9965 - val_loss: 1.9607 - val_accuracy: 0.9780
# Epoch 9/30
# 63/63 [==============================] - 11s 171ms/step - loss: 0.2127 - accuracy: 0.9915 - val_loss: 1.9355 - val_accuracy: 0.9830
# Epoch 10/30
# 63/63 [==============================] - 12s 196ms/step - loss: 0.1494 - accuracy: 0.9945 - val_loss: 1.9482 - val_accuracy: 0.9840
# Epoch 11/30
# 63/63 [==============================] - 10s 158ms/step - loss: 0.1553 - accuracy: 0.9945 - val_loss: 2.1542 - val_accuracy: 0.9810
# Epoch 12/30
# 63/63 [==============================] - 13s 195ms/step - loss: 0.1586 - accuracy: 0.9960 - val_loss: 2.0813 - val_accuracy: 0.9830
# Epoch 13/30
# 63/63 [==============================] - 13s 195ms/step - loss: 0.1785 - accuracy: 0.9960 - val_loss: 1.8971 - val_accuracy: 0.9820
# Epoch 14/30
# 63/63 [==============================] - 10s 162ms/step - loss: 0.0579 - accuracy: 0.9960 - val_loss: 1.7061 - val_accuracy: 0.9820
# Epoch 15/30
# 63/63 [==============================] - 11s 167ms/step - loss: 0.2076 - accuracy: 0.9950 - val_loss: 1.8792 - val_accuracy: 0.9840
# Epoch 16/30
# 63/63 [==============================] - 11s 166ms/step - loss: 0.1556 - accuracy: 0.9970 - val_loss: 1.9856 - val_accuracy: 0.9810
# Epoch 17/30
# 63/63 [==============================] - 12s 192ms/step - loss: 0.0887 - accuracy: 0.9960 - val_loss: 2.1148 - val_accuracy: 0.9800
# Epoch 18/30
# 63/63 [==============================] - 12s 192ms/step - loss: 0.1676 - accuracy: 0.9950 - val_loss: 2.0252 - val_accuracy: 0.9820
# Epoch 19/30
# 63/63 [==============================] - 11s 166ms/step - loss: 0.2272 - accuracy: 0.9945 - val_loss: 2.0172 - val_accuracy: 0.9790
# Epoch 20/30
# 63/63 [==============================] - 10s 160ms/step - loss: 0.1973 - accuracy: 0.9925 - val_loss: 1.9881 - val_accuracy: 0.9830
# Epoch 21/30
# 63/63 [==============================] - 11s 163ms/step - loss: 0.0622 - accuracy: 0.9980 - val_loss: 1.9885 - val_accuracy: 0.9800
# Epoch 22/30
# 63/63 [==============================] - 11s 166ms/step - loss: 0.0854 - accuracy: 0.9960 - val_loss: 2.0910 - val_accuracy: 0.9840
# Epoch 23/30
# 63/63 [==============================] - 11s 168ms/step - loss: 0.1561 - accuracy: 0.9945 - val_loss: 2.0619 - val_accuracy: 0.9810
# Epoch 24/30
# 63/63 [==============================] - 10s 161ms/step - loss: 0.1812 - accuracy: 0.9940 - val_loss: 1.8210 - val_accuracy: 0.9820
# Epoch 25/30
# 63/63 [==============================] - 11s 160ms/step - loss: 0.1738 - accuracy: 0.9940 - val_loss: 2.0262 - val_accuracy: 0.9810
# Epoch 26/30
# 63/63 [==============================] - 10s 163ms/step - loss: 0.0120 - accuracy: 0.9985 - val_loss: 1.9159 - val_accuracy: 0.9810
# Epoch 27/30
# 63/63 [==============================] - 11s 168ms/step - loss: 0.1472 - accuracy: 0.9965 - val_loss: 1.8716 - val_accuracy: 0.9810
# Epoch 28/30
# 63/63 [==============================] - 11s 170ms/step - loss: 0.0097 - accuracy: 0.9990 - val_loss: 1.9304 - val_accuracy: 0.9820
# Epoch 29/30
# 63/63 [==============================] - 11s 160ms/step - loss: 0.0749 - accuracy: 0.9955 - val_loss: 1.7343 - val_accuracy: 0.9830
# Epoch 30/30
# 63/63 [==============================] - 10s 163ms/step - loss: 0.0586 - accuracy: 0.9965 - val_loss: 2.3797 - val_accuracy: 0.9750

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# 63/63 [==============================] - 6s 90ms/step - loss: 1.8670 - accuracy: 0.9770
# 테스트 정확도: 0.977

# %% [markdown]
# ## 요약

# %%
import matplotlib.pyplot as plt
class_names = test_dataset.class_names # ['cat', 'dog']
plt.figure(figsize=(16, 16))
for images, labels in test_dataset.take(1):
  y_pred = model.predict(images)
  for i in range(12):
    ax = plt.subplot(3, 4, i + 1)
    pred_label = class_names[ 1 if y_pred[i] >=0.5 else 0 ]
    y_pred_temp = float((1-y_pred[i]) if y_pred[i] < 0.5 else y_pred[i])
    print(y_pred[i], pred_label, y_pred_temp)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(f"{pred_label}({y_pred_temp*100:.2f})%")
    plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 36ms/step
# [0.] cat 1.0
# [1.] dog 1.0
# [0.] cat 1.0
# [0.] cat 1.0
# [0.] cat 1.0
# [0.] cat 1.0
# [1.] dog 1.0
# [0.] cat 1.0
# [0.] cat 1.0
# [1.] dog 1.0
# [1.] dog 1.0
# [1.] dog 1.0
